# %%
### Merge airsea 1-min files: directly from Mule
import numpy as np
import netCDF4 as nc
import matplotlib
import matplotlib.pyplot as plt
import datetime
import os
import math
import cftime
import sys
path_nhchi = os.path.expanduser('~/Documents/projects/analytical-tools/py_nhchi/')
# adding to the system path
sys.path.insert(0, path_nhchi)

# %%
path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/hurricane_monitoring_2023/delayed_post_mission/sd-1031/'
test = os.listdir(path)
print(len(test))
# Out:
# 1008

# %%
year = '2023'
platf_num = '1042'
### folder name that hosts the airsea data
# for importing saildrone data from mule: make sure it is mounted (mule.pmel.noaa.gov)
if year == '2021':
    sd_year = ['1031','1040','1045','1048','1060']
    path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/hurricane_monitoring_2021_updated/daily_files/'+platf_num+'/'
elif year == '2022':
    sd_year = ['1031','1032','1040','1059','1078','1083','1084']
    path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/hurricane_monitoring_2022/delayed/'+platf_num+'/'
elif year == '2023':
    sd_year = ['1031','1036','1040','1041','1042','1045','1057','1064','1065','1068','1069','1083']
    # path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/hurricane_monitoring_2023/delayed/'+platf_num+'/'
    path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/hurricane_monitoring_2023/delayed_post_mission/sd-'+platf_num+'/'
elif year == '2024':
    sd_year = ['1030','1031','1036','1040','1041','1042','1045','1057','1068','1069','1083','1091']
    path = '/Volumes/disk3/projects/sdig-external/sdig/saildrone/noaa_hurricane_2024/delayed/'+platf_num+'/'

# %%
filenames_all = np.sort( os.listdir(path) )
print('Number of Files in for this directory on Mule:',len(filenames_all))
pathout = os.getcwd()+'/fig_merge_raw_airsea/'
if os.path.isdir(pathout):
    pass
else:
    os.mkdir(pathout)
### retain the filenames wanted only
filenames = np.array([])
for file in filenames_all:
    if ('saildrone' in file) & ('.nc' in file):
        filenames = np.append(filenames, file)
print('Files have "saildrone" & ".nc" in the sub-directory on Mule:',len(filenames))
print(filenames)
### the list of variables I want
vars_yes = ['latitude','longitude','time','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV',\
            'WIND_MEASUREMENT_HEIGHT_MEAN','TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN',\
                'WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT',\
                    'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
                        'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
# Out:
# Number of Files in for this directory on Mule: 367
# Files have "saildrone" & ".nc" in the sub-directory on Mule: 367
# ['saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T100000-20231017T115959-1_minutes-v1.1703005461571.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T120000-20231017T135959-1_minutes-v1.1703005462456.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T140000-20231017T155959-1_minutes-v1.1703005463209.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T160000-20231017T175959-1_minutes-v1.1703005464428.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T180000-20231017T195959-1_minutes-v1.1703005465141.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T200000-20231017T215959-1_minutes-v1.1703005466040.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T220000-20231017T235959-1_minutes-v1.1703005466993.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T000000-20231018T015959-1_minutes-v1.1703005460832.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T020000-20231018T035959-1_minutes-v1.1703005462401.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T040000-20231018T055959-1_minutes-v1.1703005463212.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T060000-20231018T075959-1_minutes-v1.1703005464066.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T080000-20231018T095959-1_minutes-v1.1703005464909.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T100000-20231018T115959-1_minutes-v1.1703005465632.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T120000-20231018T135959-1_minutes-v1.1703005466481.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T140000-20231018T155959-1_minutes-v1.1703005467279.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T160000-20231018T175959-1_minutes-v1.1703005468079.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T180000-20231018T195959-1_minutes-v1.1703005468853.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T200000-20231018T215959-1_minutes-v1.1703005469622.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T220000-20231018T235959-1_minutes-v1.1703005470421.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T000000-20231019T015959-1_minutes-v1.1703005471311.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T020000-20231019T035959-1_minutes-v1.1703005472352.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T040000-20231019T055959-1_minutes-v1.1703005473426.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T060000-20231019T075959-1_minutes-v1.1703005474243.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T080000-20231019T095959-1_minutes-v1.1703005475132.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T100000-20231019T115959-1_minutes-v1.1703005475901.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T120000-20231019T135959-1_minutes-v1.1703005476646.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T140000-20231019T155959-1_minutes-v1.1703005477911.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T160000-20231019T175959-1_minutes-v1.1703005478671.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T180000-20231019T195959-1_minutes-v1.1703005479980.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T200000-20231019T215959-1_minutes-v1.1703005480723.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T220000-20231019T235959-1_minutes-v1.1703005481478.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T000000-20231020T015959-1_minutes-v1.1703005482287.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T020000-20231020T035959-1_minutes-v1.1703005483026.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T040000-20231020T055959-1_minutes-v1.1703005483764.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T060000-20231020T075959-1_minutes-v1.1703005484578.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T080000-20231020T095959-1_minutes-v1.1703005485790.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T100000-20231020T115959-1_minutes-v1.1703005486585.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T120000-20231020T135959-1_minutes-v1.1703005487877.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T140000-20231020T155959-1_minutes-v1.1703005488588.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T160000-20231020T175959-1_minutes-v1.1703005489372.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T180000-20231020T195959-1_minutes-v1.1703005490150.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T200000-20231020T215959-1_minutes-v1.1703005490954.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T220000-20231020T235959-1_minutes-v1.1703005491928.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T000000-20231021T015959-1_minutes-v1.1703005492716.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T020000-20231021T035959-1_minutes-v1.1703005493505.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T040000-20231021T055959-1_minutes-v1.1703005494681.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T060000-20231021T075959-1_minutes-v1.1703005495515.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T080000-20231021T095959-1_minutes-v1.1703005496696.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T100000-20231021T115959-1_minutes-v1.1703005497475.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T120000-20231021T135959-1_minutes-v1.1703005498525.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T140000-20231021T155959-1_minutes-v1.1703005499294.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T160000-20231021T175959-1_minutes-v1.1703005500261.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T180000-20231021T195959-1_minutes-v1.1703005500996.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T200000-20231021T215959-1_minutes-v1.1703005501774.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T220000-20231021T235959-1_minutes-v1.1703005502519.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T000000-20231022T015959-1_minutes-v1.1703005503516.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T020000-20231022T035959-1_minutes-v1.1703005504257.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T040000-20231022T055959-1_minutes-v1.1703005504992.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T060000-20231022T075959-1_minutes-v1.1703005505765.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T080000-20231022T095959-1_minutes-v1.1703005507000.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T100000-20231022T115959-1_minutes-v1.1703005507711.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T120000-20231022T135959-1_minutes-v1.1703005508542.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T140000-20231022T155959-1_minutes-v1.1703005509377.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T160000-20231022T175959-1_minutes-v1.1703005510145.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T180000-20231022T195959-1_minutes-v1.1703005510908.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T200000-20231022T215959-1_minutes-v1.1703005511691.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T220000-20231022T235959-1_minutes-v1.1703005512474.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T000000-20231023T015959-1_minutes-v1.1703005513632.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T020000-20231023T035959-1_minutes-v1.1703005514367.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T040000-20231023T055959-1_minutes-v1.1703005515369.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T060000-20231023T075959-1_minutes-v1.1703005516160.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T080000-20231023T095959-1_minutes-v1.1703005516930.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T100000-20231023T115959-1_minutes-v1.1703005517750.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T120000-20231023T135959-1_minutes-v1.1703005518902.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T140000-20231023T155959-1_minutes-v1.1703005519708.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T160000-20231023T175959-1_minutes-v1.1703005520452.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T180000-20231023T195959-1_minutes-v1.1703005521267.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T200000-20231023T215959-1_minutes-v1.1703005522254.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T220000-20231023T235959-1_minutes-v1.1703005523023.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T000000-20231024T015959-1_minutes-v1.1703005523835.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T020000-20231024T035959-1_minutes-v1.1703005524604.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T040000-20231024T055959-1_minutes-v1.1703005525376.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T060000-20231024T075959-1_minutes-v1.1703005526092.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T080000-20231024T095959-1_minutes-v1.1703005526914.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T100000-20231024T115959-1_minutes-v1.1703005527729.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T120000-20231024T135959-1_minutes-v1.1703005528600.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T140000-20231024T155959-1_minutes-v1.1703005529389.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T160000-20231024T175959-1_minutes-v1.1703005530143.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T180000-20231024T195959-1_minutes-v1.1703005531327.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T200000-20231024T215959-1_minutes-v1.1703005532351.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T220000-20231024T235959-1_minutes-v1.1703005533171.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T000000-20231025T015959-1_minutes-v1.1703005533921.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T020000-20231025T035959-1_minutes-v1.1703005535008.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T040000-20231025T055959-1_minutes-v1.1703005535749.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T060000-20231025T075959-1_minutes-v1.1703005536495.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T080000-20231025T095959-1_minutes-v1.1703005537351.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T100000-20231025T115959-1_minutes-v1.1703005538068.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T120000-20231025T135959-1_minutes-v1.1703005538881.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T140000-20231025T155959-1_minutes-v1.1703005539612.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T160000-20231025T175959-1_minutes-v1.1703005540436.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T180000-20231025T195959-1_minutes-v1.1703005541216.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T200000-20231025T215959-1_minutes-v1.1703005542083.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T220000-20231025T235959-1_minutes-v1.1703005542912.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T000000-20231026T015959-1_minutes-v1.1703005543681.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T020000-20231026T035959-1_minutes-v1.1703005544377.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T040000-20231026T055959-1_minutes-v1.1703005545369.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T060000-20231026T075959-1_minutes-v1.1703005546151.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T080000-20231026T095959-1_minutes-v1.1703005547430.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T100000-20231026T115959-1_minutes-v1.1703005548154.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T120000-20231026T135959-1_minutes-v1.1703005548925.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T140000-20231026T155959-1_minutes-v1.1703005549696.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T160000-20231026T175959-1_minutes-v1.1703005550515.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T180000-20231026T195959-1_minutes-v1.1703005551350.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T200000-20231026T215959-1_minutes-v1.1703005552249.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T220000-20231026T235959-1_minutes-v1.1703005553400.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T000000-20231027T015959-1_minutes-v1.1703005554193.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T020000-20231027T035959-1_minutes-v1.1703005555244.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T040000-20231027T055959-1_minutes-v1.1703005556526.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T060000-20231027T075959-1_minutes-v1.1703005557316.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T080000-20231027T095959-1_minutes-v1.1703005558085.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T100000-20231027T115959-1_minutes-v1.1703005559294.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T120000-20231027T135959-1_minutes-v1.1703005560095.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T140000-20231027T155959-1_minutes-v1.1703005560856.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T160000-20231027T175959-1_minutes-v1.1703005561704.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T180000-20231027T195959-1_minutes-v1.1703005562496.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T200000-20231027T215959-1_minutes-v1.1703005563234.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T220000-20231027T235959-1_minutes-v1.1703005563961.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T000000-20231028T015959-1_minutes-v1.1703005564744.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T020000-20231028T035959-1_minutes-v1.1703005565523.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T040000-20231028T055959-1_minutes-v1.1703005566362.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T060000-20231028T075959-1_minutes-v1.1703005567216.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T080000-20231028T095959-1_minutes-v1.1703005568020.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T100000-20231028T115959-1_minutes-v1.1703005568769.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T120000-20231028T135959-1_minutes-v1.1703005569568.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T140000-20231028T155959-1_minutes-v1.1703005570406.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T160000-20231028T175959-1_minutes-v1.1703005571683.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T180000-20231028T195959-1_minutes-v1.1703005572909.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T200000-20231028T215959-1_minutes-v1.1703005573682.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T220000-20231028T235959-1_minutes-v1.1703005574451.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T000000-20231029T015959-1_minutes-v1.1703005575458.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T020000-20231029T035959-1_minutes-v1.1703005576215.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T040000-20231029T055959-1_minutes-v1.1703005577041.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T060000-20231029T075959-1_minutes-v1.1703005578179.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T080000-20231029T095959-1_minutes-v1.1703005578957.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T100000-20231029T115959-1_minutes-v1.1703005579756.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T120000-20231029T135959-1_minutes-v1.1703005580622.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T140000-20231029T155959-1_minutes-v1.1703005581444.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T160000-20231029T175959-1_minutes-v1.1703005582232.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T180000-20231029T195959-1_minutes-v1.1703005583083.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T200000-20231029T215959-1_minutes-v1.1703005583810.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T220000-20231029T235959-1_minutes-v1.1703005584591.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T000000-20231030T015959-1_minutes-v1.1703005585393.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T020000-20231030T035959-1_minutes-v1.1703005586432.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T040000-20231030T055959-1_minutes-v1.1703005587166.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T060000-20231030T075959-1_minutes-v1.1703005587927.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T080000-20231030T095959-1_minutes-v1.1703005588704.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T100000-20231030T115959-1_minutes-v1.1703005589529.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T120000-20231030T135959-1_minutes-v1.1703005590340.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T140000-20231030T155959-1_minutes-v1.1703005591144.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T160000-20231030T175959-1_minutes-v1.1703005591874.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T180000-20231030T195959-1_minutes-v1.1703005592932.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T200000-20231030T215959-1_minutes-v1.1703005593776.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T220000-20231030T235959-1_minutes-v1.1703005594880.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T000000-20231031T015959-1_minutes-v1.1703005595640.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T020000-20231031T035959-1_minutes-v1.1703005596467.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T040000-20231031T055959-1_minutes-v1.1703005597427.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T060000-20231031T075959-1_minutes-v1.1703005598438.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T080000-20231031T095959-1_minutes-v1.1703005599654.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T100000-20231031T115959-1_minutes-v1.1703005600443.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T120000-20231031T135959-1_minutes-v1.1703005601197.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T140000-20231031T155959-1_minutes-v1.1703005601981.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T160000-20231031T175959-1_minutes-v1.1703005602735.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T180000-20231031T195959-1_minutes-v1.1703005603491.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T200000-20231031T215959-1_minutes-v1.1703005604321.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T220000-20231031T235959-1_minutes-v1.1703005605114.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T000000-20231101T015959-1_minutes-v1.1703005605933.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T020000-20231101T035959-1_minutes-v1.1703005606951.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T040000-20231101T055959-1_minutes-v1.1703005607711.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T060000-20231101T075959-1_minutes-v1.1703005608496.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T080000-20231101T095959-1_minutes-v1.1703005609296.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T100000-20231101T115959-1_minutes-v1.1703005610077.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T120000-20231101T135959-1_minutes-v1.1703005610852.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T140000-20231101T155959-1_minutes-v1.1703005611840.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T160000-20231101T175959-1_minutes-v1.1703005612594.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T180000-20231101T195959-1_minutes-v1.1703005613318.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T200000-20231101T215959-1_minutes-v1.1703005614137.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T220000-20231101T235959-1_minutes-v1.1703005614945.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T000000-20231102T015959-1_minutes-v1.1703005615796.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T020000-20231102T035959-1_minutes-v1.1703005616580.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T040000-20231102T055959-1_minutes-v1.1703005617354.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T060000-20231102T075959-1_minutes-v1.1703005618355.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T080000-20231102T095959-1_minutes-v1.1703005619530.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T100000-20231102T115959-1_minutes-v1.1703005620290.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T120000-20231102T135959-1_minutes-v1.1703005621074.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T140000-20231102T155959-1_minutes-v1.1703005621874.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T160000-20231102T175959-1_minutes-v1.1703005622738.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T180000-20231102T195959-1_minutes-v1.1703005623515.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T200000-20231102T215959-1_minutes-v1.1703005624290.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T220000-20231102T235959-1_minutes-v1.1703005625113.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T000000-20231103T015959-1_minutes-v1.1703005625967.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T020000-20231103T035959-1_minutes-v1.1703005627073.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T040000-20231103T055959-1_minutes-v1.1703005627911.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T060000-20231103T075959-1_minutes-v1.1703005629104.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T080000-20231103T095959-1_minutes-v1.1703005629906.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T100000-20231103T115959-1_minutes-v1.1703005630661.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T120000-20231103T135959-1_minutes-v1.1703005631476.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T140000-20231103T155959-1_minutes-v1.1703005632271.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T160000-20231103T175959-1_minutes-v1.1703005633031.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T180000-20231103T195959-1_minutes-v1.1703005633800.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T200000-20231103T215959-1_minutes-v1.1703005634802.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T220000-20231103T235959-1_minutes-v1.1703005635569.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T000000-20231104T015959-1_minutes-v1.1703005636511.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T020000-20231104T035959-1_minutes-v1.1703005637303.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T040000-20231104T055959-1_minutes-v1.1703005638088.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T060000-20231104T075959-1_minutes-v1.1703005638846.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T080000-20231104T095959-1_minutes-v1.1703005639722.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T100000-20231104T115959-1_minutes-v1.1703005640482.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T120000-20231104T135959-1_minutes-v1.1703005641558.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T140000-20231104T155959-1_minutes-v1.1703005642394.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T160000-20231104T175959-1_minutes-v1.1703005643169.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T180000-20231104T195959-1_minutes-v1.1703005643956.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T200000-20231104T215959-1_minutes-v1.1703005644773.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T220000-20231104T235959-1_minutes-v1.1703005645551.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T000000-20231105T015959-1_minutes-v1.1703005646328.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T020000-20231105T035959-1_minutes-v1.1703005647246.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T040000-20231105T055959-1_minutes-v1.1703005648093.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T060000-20231105T075959-1_minutes-v1.1703005648954.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T080000-20231105T095959-1_minutes-v1.1703005649692.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T100000-20231105T115959-1_minutes-v1.1703005650638.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T120000-20231105T135959-1_minutes-v1.1703005651429.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T140000-20231105T155959-1_minutes-v1.1703005652310.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T160000-20231105T175959-1_minutes-v1.1703005653177.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T180000-20231105T195959-1_minutes-v1.1703005653975.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T200000-20231105T215959-1_minutes-v1.1703005654730.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T220000-20231105T235959-1_minutes-v1.1703005655516.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T000000-20231106T015959-1_minutes-v1.1703005656276.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T020000-20231106T035959-1_minutes-v1.1703005657612.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T040000-20231106T055959-1_minutes-v1.1703005658363.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T060000-20231106T075959-1_minutes-v1.1703005659115.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T080000-20231106T095959-1_minutes-v1.1703005659887.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T100000-20231106T115959-1_minutes-v1.1703005661144.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T120000-20231106T135959-1_minutes-v1.1703005662131.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T140000-20231106T155959-1_minutes-v1.1703005662972.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T160000-20231106T175959-1_minutes-v1.1703005663767.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T180000-20231106T195959-1_minutes-v1.1703005664840.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T200000-20231106T215959-1_minutes-v1.1703005665828.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T220000-20231106T235959-1_minutes-v1.1703005666668.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T000000-20231107T015959-1_minutes-v1.1703005667492.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T020000-20231107T035959-1_minutes-v1.1703005668501.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T040000-20231107T055959-1_minutes-v1.1703005669261.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T060000-20231107T075959-1_minutes-v1.1703005670027.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T080000-20231107T095959-1_minutes-v1.1703005670751.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T100000-20231107T115959-1_minutes-v1.1703005671742.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T120000-20231107T135959-1_minutes-v1.1703005672571.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T140000-20231107T155959-1_minutes-v1.1703005673822.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T160000-20231107T175959-1_minutes-v1.1703005675093.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T180000-20231107T195959-1_minutes-v1.1703005675895.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T200000-20231107T215959-1_minutes-v1.1703005677084.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T220000-20231107T235959-1_minutes-v1.1703005678064.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T000000-20231108T015959-1_minutes-v1.1703005678927.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T020000-20231108T035959-1_minutes-v1.1703005679713.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T040000-20231108T055959-1_minutes-v1.1703005680671.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T060000-20231108T075959-1_minutes-v1.1703005681428.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T080000-20231108T095959-1_minutes-v1.1703005682158.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T100000-20231108T115959-1_minutes-v1.1703005682954.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T120000-20231108T135959-1_minutes-v1.1703005683687.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T140000-20231108T155959-1_minutes-v1.1703005684513.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T160000-20231108T175959-1_minutes-v1.1703005685246.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T180000-20231108T195959-1_minutes-v1.1703005686067.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T200000-20231108T215959-1_minutes-v1.1703005686888.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T220000-20231108T235959-1_minutes-v1.1703005687694.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T000000-20231109T015959-1_minutes-v1.1703005688447.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T020000-20231109T035959-1_minutes-v1.1703005689246.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T040000-20231109T055959-1_minutes-v1.1703005690066.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T060000-20231109T075959-1_minutes-v1.1703005691031.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T080000-20231109T095959-1_minutes-v1.1703005691788.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T100000-20231109T115959-1_minutes-v1.1703005692552.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T120000-20231109T135959-1_minutes-v1.1703005693337.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T140000-20231109T155959-1_minutes-v1.1703005694058.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T160000-20231109T175959-1_minutes-v1.1703005694842.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T180000-20231109T195959-1_minutes-v1.1703005695609.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T200000-20231109T215959-1_minutes-v1.1703005696440.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T220000-20231109T235959-1_minutes-v1.1703005697393.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T000000-20231110T015959-1_minutes-v1.1703005698121.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T020000-20231110T035959-1_minutes-v1.1703005698868.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T040000-20231110T055959-1_minutes-v1.1703005699691.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T060000-20231110T075959-1_minutes-v1.1703005700760.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T080000-20231110T095959-1_minutes-v1.1703005701518.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T100000-20231110T115959-1_minutes-v1.1703005702361.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T120000-20231110T135959-1_minutes-v1.1703005703145.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T140000-20231110T155959-1_minutes-v1.1703005703897.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T160000-20231110T175959-1_minutes-v1.1703005704681.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T180000-20231110T195959-1_minutes-v1.1703005705483.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T200000-20231110T215959-1_minutes-v1.1703005706364.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T220000-20231110T235959-1_minutes-v1.1703005707088.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T000000-20231111T015959-1_minutes-v1.1703005707864.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T020000-20231111T035959-1_minutes-v1.1703005709286.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T040000-20231111T055959-1_minutes-v1.1703005710294.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T060000-20231111T075959-1_minutes-v1.1703005711062.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T080000-20231111T095959-1_minutes-v1.1703005712159.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T100000-20231111T115959-1_minutes-v1.1703005712949.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T120000-20231111T135959-1_minutes-v1.1703005713730.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T140000-20231111T155959-1_minutes-v1.1703005714559.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T160000-20231111T175959-1_minutes-v1.1703005715329.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T180000-20231111T195959-1_minutes-v1.1703005716296.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T200000-20231111T215959-1_minutes-v1.1703005717167.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T220000-20231111T235959-1_minutes-v1.1703005717963.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T000000-20231112T015959-1_minutes-v1.1703005719170.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T020000-20231112T035959-1_minutes-v1.1703005719961.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T040000-20231112T055959-1_minutes-v1.1703005720720.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T060000-20231112T075959-1_minutes-v1.1703005721488.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T080000-20231112T095959-1_minutes-v1.1703005722237.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T100000-20231112T115959-1_minutes-v1.1703005723269.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T120000-20231112T135959-1_minutes-v1.1703005724539.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T140000-20231112T155959-1_minutes-v1.1703005725465.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T160000-20231112T175959-1_minutes-v1.1703005726741.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T180000-20231112T195959-1_minutes-v1.1703005727589.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T200000-20231112T215959-1_minutes-v1.1703005728497.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T220000-20231112T235959-1_minutes-v1.1703005729231.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T000000-20231113T015959-1_minutes-v1.1703005729997.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T020000-20231113T035959-1_minutes-v1.1703005730772.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T040000-20231113T055959-1_minutes-v1.1703005731637.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T060000-20231113T075959-1_minutes-v1.1703005732442.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T080000-20231113T095959-1_minutes-v1.1703005733455.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T100000-20231113T115959-1_minutes-v1.1703005734260.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T120000-20231113T135959-1_minutes-v1.1703005734976.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T140000-20231113T155959-1_minutes-v1.1703005735740.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T160000-20231113T175959-1_minutes-v1.1703005736460.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T180000-20231113T195959-1_minutes-v1.1703005737257.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T200000-20231113T215959-1_minutes-v1.1703005738017.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T220000-20231113T235959-1_minutes-v1.1703005738782.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T000000-20231114T015959-1_minutes-v1.1703005739548.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T020000-20231114T035959-1_minutes-v1.1703005740327.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T040000-20231114T055959-1_minutes-v1.1703005741154.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T060000-20231114T075959-1_minutes-v1.1703005741934.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T080000-20231114T095959-1_minutes-v1.1703005742734.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T100000-20231114T115959-1_minutes-v1.1703005743469.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T120000-20231114T135959-1_minutes-v1.1703005744539.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T140000-20231114T155959-1_minutes-v1.1703005745328.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T160000-20231114T175959-1_minutes-v1.1703005746220.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T180000-20231114T195959-1_minutes-v1.1703005747082.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T200000-20231114T215959-1_minutes-v1.1703005747867.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T220000-20231114T235959-1_minutes-v1.1703005748731.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T000000-20231115T015959-1_minutes-v1.1703005749664.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T020000-20231115T035959-1_minutes-v1.1703005750410.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T040000-20231115T055959-1_minutes-v1.1703005751200.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T060000-20231115T075959-1_minutes-v1.1703005751961.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T080000-20231115T095959-1_minutes-v1.1703005752851.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T100000-20231115T115959-1_minutes-v1.1703005754161.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T120000-20231115T135959-1_minutes-v1.1703005754915.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T140000-20231115T155959-1_minutes-v1.1703005755763.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T160000-20231115T175959-1_minutes-v1.1703005756586.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T180000-20231115T195959-1_minutes-v1.1703005757601.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T200000-20231115T215959-1_minutes-v1.1703005758463.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T220000-20231115T235959-1_minutes-v1.1703005759250.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T000000-20231116T015959-1_minutes-v1.1703005760035.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T020000-20231116T035959-1_minutes-v1.1703005760810.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T040000-20231116T055959-1_minutes-v1.1703005761653.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T060000-20231116T075959-1_minutes-v1.1703005762515.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T080000-20231116T095959-1_minutes-v1.1703005763352.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T100000-20231116T115959-1_minutes-v1.1703005764174.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T120000-20231116T135959-1_minutes-v1.1703005764935.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T140000-20231116T155959-1_minutes-v1.1703005765738.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T160000-20231116T175959-1_minutes-v1.1703005766588.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T180000-20231116T195959-1_minutes-v1.1703005767662.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T200000-20231116T215959-1_minutes-v1.1703005768623.nc'
#  'saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T220000-20231116T235959-1_minutes-v1.1703005769340.nc']

# %%
### create a dictionary
vars_dic = {}
vars_dic_attr = {}
attr = ['long_name','units','installed_height']
vars_no_installed_height = ['latitude','longitude','time']
### find the first uncorrupted file
for f in range( len(filenames) ):
    try: # block raising an exception
        ds = nc.Dataset(path+'/'+filenames[0])
        varnms = list( ds.variables.keys() )
        break
    except: ### do nothing on exception
        pass

### add empty items to the dictionary 
for i in range( len(varnms) ):
    vkey = varnms[i]
    if vkey in vars_yes:
        item = ds.variables[vkey][:]
        vars_dic[vkey] = np.empty( item.shape )
        attr_in_vkey = ds.variables[vkey].ncattrs()
        ### record attributes
        for a in range( len(attr) ):
            if attr[a] in attr_in_vkey: # if attribute of this vkey exist, write out
                if (attr[a] == 'installed_height') & (vkey in vars_no_installed_height):
                    pass
                else:
                    str_eval = "ds.variables['" + vkey + "']." + attr[a]
                    vars_dic_attr[vkey+'-'+attr[a]] = eval(str_eval)
        # print(vkey, item.shape, vars_dic[vkey].shape)
print(len(varnms),'variables in nc file &', len(vars_dic),'variables are selected to append')

### go through each daily nc file & append the selected variables 
print('Start going through',len(filenames),'nc file & append selected variables')
filenames_canopen = []
numOK = 0
numBAD = 0
vars_exists = []
for f in range( len(filenames) ):
    try: # block raising an exception
        ds = nc.Dataset(path+'/'+filenames[f])
        filenames_canopen.append(filenames[f])
        numOK = numOK + 1
        for i in range( len(varnms) ):
            vkey = varnms[i]
            if (vkey in vars_yes): #& (vkey not in vars_nostack):
                # print(vkey)
                vars_exists.append(vkey)
                vkey = varnms[i]
                item_old = vars_dic[vkey]
                item_app = np.squeeze( ds.variables[vkey][:] )
                ### append in time dimension only
                if numOK == 1:
                    vars_dic[vkey] = item_app
                else:
                    vars_dic[vkey] = np.concatenate( (item_old, item_app),axis=0 )
        print('Done',filenames[f])
    except:
        numBAD = numBAD + 1
        print(filenames[f],'cannot be open. skip')
print(numOK,'can be open.')
print(numBAD,'cannot be open.')
print('----- Done going through nc files & append selected variables -----')
# Out:
# 77 variables in nc file & 23 variables are selected to append
# Start going through 367 nc file & append selected variables
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T100000-20231017T115959-1_minutes-v1.1703005461571.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T120000-20231017T135959-1_minutes-v1.1703005462456.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T140000-20231017T155959-1_minutes-v1.1703005463209.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T160000-20231017T175959-1_minutes-v1.1703005464428.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T180000-20231017T195959-1_minutes-v1.1703005465141.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T200000-20231017T215959-1_minutes-v1.1703005466040.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231017T220000-20231017T235959-1_minutes-v1.1703005466993.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T000000-20231018T015959-1_minutes-v1.1703005460832.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T020000-20231018T035959-1_minutes-v1.1703005462401.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T040000-20231018T055959-1_minutes-v1.1703005463212.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T060000-20231018T075959-1_minutes-v1.1703005464066.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T080000-20231018T095959-1_minutes-v1.1703005464909.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T100000-20231018T115959-1_minutes-v1.1703005465632.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T120000-20231018T135959-1_minutes-v1.1703005466481.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T140000-20231018T155959-1_minutes-v1.1703005467279.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T160000-20231018T175959-1_minutes-v1.1703005468079.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T180000-20231018T195959-1_minutes-v1.1703005468853.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T200000-20231018T215959-1_minutes-v1.1703005469622.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231018T220000-20231018T235959-1_minutes-v1.1703005470421.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T000000-20231019T015959-1_minutes-v1.1703005471311.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T020000-20231019T035959-1_minutes-v1.1703005472352.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T040000-20231019T055959-1_minutes-v1.1703005473426.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T060000-20231019T075959-1_minutes-v1.1703005474243.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T080000-20231019T095959-1_minutes-v1.1703005475132.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T100000-20231019T115959-1_minutes-v1.1703005475901.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T120000-20231019T135959-1_minutes-v1.1703005476646.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T140000-20231019T155959-1_minutes-v1.1703005477911.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T160000-20231019T175959-1_minutes-v1.1703005478671.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T180000-20231019T195959-1_minutes-v1.1703005479980.nc
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T200000-20231019T215959-1_minutes-v1.1703005480723.nc cannot be open. skip
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231019T220000-20231019T235959-1_minutes-v1.1703005481478.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T000000-20231020T015959-1_minutes-v1.1703005482287.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T020000-20231020T035959-1_minutes-v1.1703005483026.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T040000-20231020T055959-1_minutes-v1.1703005483764.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T060000-20231020T075959-1_minutes-v1.1703005484578.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T080000-20231020T095959-1_minutes-v1.1703005485790.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T100000-20231020T115959-1_minutes-v1.1703005486585.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T120000-20231020T135959-1_minutes-v1.1703005487877.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T140000-20231020T155959-1_minutes-v1.1703005488588.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T160000-20231020T175959-1_minutes-v1.1703005489372.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T180000-20231020T195959-1_minutes-v1.1703005490150.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T200000-20231020T215959-1_minutes-v1.1703005490954.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231020T220000-20231020T235959-1_minutes-v1.1703005491928.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T000000-20231021T015959-1_minutes-v1.1703005492716.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T020000-20231021T035959-1_minutes-v1.1703005493505.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T040000-20231021T055959-1_minutes-v1.1703005494681.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T060000-20231021T075959-1_minutes-v1.1703005495515.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T080000-20231021T095959-1_minutes-v1.1703005496696.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T100000-20231021T115959-1_minutes-v1.1703005497475.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T120000-20231021T135959-1_minutes-v1.1703005498525.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T140000-20231021T155959-1_minutes-v1.1703005499294.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T160000-20231021T175959-1_minutes-v1.1703005500261.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T180000-20231021T195959-1_minutes-v1.1703005500996.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T200000-20231021T215959-1_minutes-v1.1703005501774.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231021T220000-20231021T235959-1_minutes-v1.1703005502519.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T000000-20231022T015959-1_minutes-v1.1703005503516.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T020000-20231022T035959-1_minutes-v1.1703005504257.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T040000-20231022T055959-1_minutes-v1.1703005504992.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T060000-20231022T075959-1_minutes-v1.1703005505765.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T080000-20231022T095959-1_minutes-v1.1703005507000.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T100000-20231022T115959-1_minutes-v1.1703005507711.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T120000-20231022T135959-1_minutes-v1.1703005508542.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T140000-20231022T155959-1_minutes-v1.1703005509377.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T160000-20231022T175959-1_minutes-v1.1703005510145.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T180000-20231022T195959-1_minutes-v1.1703005510908.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T200000-20231022T215959-1_minutes-v1.1703005511691.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231022T220000-20231022T235959-1_minutes-v1.1703005512474.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T000000-20231023T015959-1_minutes-v1.1703005513632.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T020000-20231023T035959-1_minutes-v1.1703005514367.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T040000-20231023T055959-1_minutes-v1.1703005515369.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T060000-20231023T075959-1_minutes-v1.1703005516160.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T080000-20231023T095959-1_minutes-v1.1703005516930.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T100000-20231023T115959-1_minutes-v1.1703005517750.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T120000-20231023T135959-1_minutes-v1.1703005518902.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T140000-20231023T155959-1_minutes-v1.1703005519708.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T160000-20231023T175959-1_minutes-v1.1703005520452.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T180000-20231023T195959-1_minutes-v1.1703005521267.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T200000-20231023T215959-1_minutes-v1.1703005522254.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231023T220000-20231023T235959-1_minutes-v1.1703005523023.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T000000-20231024T015959-1_minutes-v1.1703005523835.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T020000-20231024T035959-1_minutes-v1.1703005524604.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T040000-20231024T055959-1_minutes-v1.1703005525376.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T060000-20231024T075959-1_minutes-v1.1703005526092.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T080000-20231024T095959-1_minutes-v1.1703005526914.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T100000-20231024T115959-1_minutes-v1.1703005527729.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T120000-20231024T135959-1_minutes-v1.1703005528600.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T140000-20231024T155959-1_minutes-v1.1703005529389.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T160000-20231024T175959-1_minutes-v1.1703005530143.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T180000-20231024T195959-1_minutes-v1.1703005531327.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T200000-20231024T215959-1_minutes-v1.1703005532351.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231024T220000-20231024T235959-1_minutes-v1.1703005533171.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T000000-20231025T015959-1_minutes-v1.1703005533921.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T020000-20231025T035959-1_minutes-v1.1703005535008.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T040000-20231025T055959-1_minutes-v1.1703005535749.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T060000-20231025T075959-1_minutes-v1.1703005536495.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T080000-20231025T095959-1_minutes-v1.1703005537351.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T100000-20231025T115959-1_minutes-v1.1703005538068.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T120000-20231025T135959-1_minutes-v1.1703005538881.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T140000-20231025T155959-1_minutes-v1.1703005539612.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T160000-20231025T175959-1_minutes-v1.1703005540436.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T180000-20231025T195959-1_minutes-v1.1703005541216.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T200000-20231025T215959-1_minutes-v1.1703005542083.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231025T220000-20231025T235959-1_minutes-v1.1703005542912.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T000000-20231026T015959-1_minutes-v1.1703005543681.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T020000-20231026T035959-1_minutes-v1.1703005544377.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T040000-20231026T055959-1_minutes-v1.1703005545369.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T060000-20231026T075959-1_minutes-v1.1703005546151.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T080000-20231026T095959-1_minutes-v1.1703005547430.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T100000-20231026T115959-1_minutes-v1.1703005548154.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T120000-20231026T135959-1_minutes-v1.1703005548925.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T140000-20231026T155959-1_minutes-v1.1703005549696.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T160000-20231026T175959-1_minutes-v1.1703005550515.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T180000-20231026T195959-1_minutes-v1.1703005551350.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T200000-20231026T215959-1_minutes-v1.1703005552249.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231026T220000-20231026T235959-1_minutes-v1.1703005553400.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T000000-20231027T015959-1_minutes-v1.1703005554193.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T020000-20231027T035959-1_minutes-v1.1703005555244.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T040000-20231027T055959-1_minutes-v1.1703005556526.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T060000-20231027T075959-1_minutes-v1.1703005557316.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T080000-20231027T095959-1_minutes-v1.1703005558085.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T100000-20231027T115959-1_minutes-v1.1703005559294.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T120000-20231027T135959-1_minutes-v1.1703005560095.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T140000-20231027T155959-1_minutes-v1.1703005560856.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T160000-20231027T175959-1_minutes-v1.1703005561704.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T180000-20231027T195959-1_minutes-v1.1703005562496.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T200000-20231027T215959-1_minutes-v1.1703005563234.nc
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231027T220000-20231027T235959-1_minutes-v1.1703005563961.nc cannot be open. skip
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T000000-20231028T015959-1_minutes-v1.1703005564744.nc cannot be open. skip
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T020000-20231028T035959-1_minutes-v1.1703005565523.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T040000-20231028T055959-1_minutes-v1.1703005566362.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T060000-20231028T075959-1_minutes-v1.1703005567216.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T080000-20231028T095959-1_minutes-v1.1703005568020.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T100000-20231028T115959-1_minutes-v1.1703005568769.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T120000-20231028T135959-1_minutes-v1.1703005569568.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T140000-20231028T155959-1_minutes-v1.1703005570406.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T160000-20231028T175959-1_minutes-v1.1703005571683.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T180000-20231028T195959-1_minutes-v1.1703005572909.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T200000-20231028T215959-1_minutes-v1.1703005573682.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231028T220000-20231028T235959-1_minutes-v1.1703005574451.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T000000-20231029T015959-1_minutes-v1.1703005575458.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T020000-20231029T035959-1_minutes-v1.1703005576215.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T040000-20231029T055959-1_minutes-v1.1703005577041.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T060000-20231029T075959-1_minutes-v1.1703005578179.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T080000-20231029T095959-1_minutes-v1.1703005578957.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T100000-20231029T115959-1_minutes-v1.1703005579756.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T120000-20231029T135959-1_minutes-v1.1703005580622.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T140000-20231029T155959-1_minutes-v1.1703005581444.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T160000-20231029T175959-1_minutes-v1.1703005582232.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T180000-20231029T195959-1_minutes-v1.1703005583083.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T200000-20231029T215959-1_minutes-v1.1703005583810.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231029T220000-20231029T235959-1_minutes-v1.1703005584591.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T000000-20231030T015959-1_minutes-v1.1703005585393.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T020000-20231030T035959-1_minutes-v1.1703005586432.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T040000-20231030T055959-1_minutes-v1.1703005587166.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T060000-20231030T075959-1_minutes-v1.1703005587927.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T080000-20231030T095959-1_minutes-v1.1703005588704.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T100000-20231030T115959-1_minutes-v1.1703005589529.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T120000-20231030T135959-1_minutes-v1.1703005590340.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T140000-20231030T155959-1_minutes-v1.1703005591144.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T160000-20231030T175959-1_minutes-v1.1703005591874.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T180000-20231030T195959-1_minutes-v1.1703005592932.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T200000-20231030T215959-1_minutes-v1.1703005593776.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231030T220000-20231030T235959-1_minutes-v1.1703005594880.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T000000-20231031T015959-1_minutes-v1.1703005595640.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T020000-20231031T035959-1_minutes-v1.1703005596467.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T040000-20231031T055959-1_minutes-v1.1703005597427.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T060000-20231031T075959-1_minutes-v1.1703005598438.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T080000-20231031T095959-1_minutes-v1.1703005599654.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T100000-20231031T115959-1_minutes-v1.1703005600443.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T120000-20231031T135959-1_minutes-v1.1703005601197.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T140000-20231031T155959-1_minutes-v1.1703005601981.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T160000-20231031T175959-1_minutes-v1.1703005602735.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T180000-20231031T195959-1_minutes-v1.1703005603491.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T200000-20231031T215959-1_minutes-v1.1703005604321.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231031T220000-20231031T235959-1_minutes-v1.1703005605114.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T000000-20231101T015959-1_minutes-v1.1703005605933.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T020000-20231101T035959-1_minutes-v1.1703005606951.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T040000-20231101T055959-1_minutes-v1.1703005607711.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T060000-20231101T075959-1_minutes-v1.1703005608496.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T080000-20231101T095959-1_minutes-v1.1703005609296.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T100000-20231101T115959-1_minutes-v1.1703005610077.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T120000-20231101T135959-1_minutes-v1.1703005610852.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T140000-20231101T155959-1_minutes-v1.1703005611840.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T160000-20231101T175959-1_minutes-v1.1703005612594.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T180000-20231101T195959-1_minutes-v1.1703005613318.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T200000-20231101T215959-1_minutes-v1.1703005614137.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231101T220000-20231101T235959-1_minutes-v1.1703005614945.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T000000-20231102T015959-1_minutes-v1.1703005615796.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T020000-20231102T035959-1_minutes-v1.1703005616580.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T040000-20231102T055959-1_minutes-v1.1703005617354.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T060000-20231102T075959-1_minutes-v1.1703005618355.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T080000-20231102T095959-1_minutes-v1.1703005619530.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T100000-20231102T115959-1_minutes-v1.1703005620290.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T120000-20231102T135959-1_minutes-v1.1703005621074.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T140000-20231102T155959-1_minutes-v1.1703005621874.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T160000-20231102T175959-1_minutes-v1.1703005622738.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T180000-20231102T195959-1_minutes-v1.1703005623515.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T200000-20231102T215959-1_minutes-v1.1703005624290.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231102T220000-20231102T235959-1_minutes-v1.1703005625113.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T000000-20231103T015959-1_minutes-v1.1703005625967.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T020000-20231103T035959-1_minutes-v1.1703005627073.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T040000-20231103T055959-1_minutes-v1.1703005627911.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T060000-20231103T075959-1_minutes-v1.1703005629104.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T080000-20231103T095959-1_minutes-v1.1703005629906.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T100000-20231103T115959-1_minutes-v1.1703005630661.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T120000-20231103T135959-1_minutes-v1.1703005631476.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T140000-20231103T155959-1_minutes-v1.1703005632271.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T160000-20231103T175959-1_minutes-v1.1703005633031.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T180000-20231103T195959-1_minutes-v1.1703005633800.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T200000-20231103T215959-1_minutes-v1.1703005634802.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231103T220000-20231103T235959-1_minutes-v1.1703005635569.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T000000-20231104T015959-1_minutes-v1.1703005636511.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T020000-20231104T035959-1_minutes-v1.1703005637303.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T040000-20231104T055959-1_minutes-v1.1703005638088.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T060000-20231104T075959-1_minutes-v1.1703005638846.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T080000-20231104T095959-1_minutes-v1.1703005639722.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T100000-20231104T115959-1_minutes-v1.1703005640482.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T120000-20231104T135959-1_minutes-v1.1703005641558.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T140000-20231104T155959-1_minutes-v1.1703005642394.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T160000-20231104T175959-1_minutes-v1.1703005643169.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T180000-20231104T195959-1_minutes-v1.1703005643956.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T200000-20231104T215959-1_minutes-v1.1703005644773.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231104T220000-20231104T235959-1_minutes-v1.1703005645551.nc
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T000000-20231105T015959-1_minutes-v1.1703005646328.nc cannot be open. skip
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T020000-20231105T035959-1_minutes-v1.1703005647246.nc cannot be open. skip
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T040000-20231105T055959-1_minutes-v1.1703005648093.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T060000-20231105T075959-1_minutes-v1.1703005648954.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T080000-20231105T095959-1_minutes-v1.1703005649692.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T100000-20231105T115959-1_minutes-v1.1703005650638.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T120000-20231105T135959-1_minutes-v1.1703005651429.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T140000-20231105T155959-1_minutes-v1.1703005652310.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T160000-20231105T175959-1_minutes-v1.1703005653177.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T180000-20231105T195959-1_minutes-v1.1703005653975.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T200000-20231105T215959-1_minutes-v1.1703005654730.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231105T220000-20231105T235959-1_minutes-v1.1703005655516.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T000000-20231106T015959-1_minutes-v1.1703005656276.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T020000-20231106T035959-1_minutes-v1.1703005657612.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T040000-20231106T055959-1_minutes-v1.1703005658363.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T060000-20231106T075959-1_minutes-v1.1703005659115.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T080000-20231106T095959-1_minutes-v1.1703005659887.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T100000-20231106T115959-1_minutes-v1.1703005661144.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T120000-20231106T135959-1_minutes-v1.1703005662131.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T140000-20231106T155959-1_minutes-v1.1703005662972.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T160000-20231106T175959-1_minutes-v1.1703005663767.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T180000-20231106T195959-1_minutes-v1.1703005664840.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T200000-20231106T215959-1_minutes-v1.1703005665828.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231106T220000-20231106T235959-1_minutes-v1.1703005666668.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T000000-20231107T015959-1_minutes-v1.1703005667492.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T020000-20231107T035959-1_minutes-v1.1703005668501.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T040000-20231107T055959-1_minutes-v1.1703005669261.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T060000-20231107T075959-1_minutes-v1.1703005670027.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T080000-20231107T095959-1_minutes-v1.1703005670751.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T100000-20231107T115959-1_minutes-v1.1703005671742.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T120000-20231107T135959-1_minutes-v1.1703005672571.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T140000-20231107T155959-1_minutes-v1.1703005673822.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T160000-20231107T175959-1_minutes-v1.1703005675093.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T180000-20231107T195959-1_minutes-v1.1703005675895.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T200000-20231107T215959-1_minutes-v1.1703005677084.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231107T220000-20231107T235959-1_minutes-v1.1703005678064.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T000000-20231108T015959-1_minutes-v1.1703005678927.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T020000-20231108T035959-1_minutes-v1.1703005679713.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T040000-20231108T055959-1_minutes-v1.1703005680671.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T060000-20231108T075959-1_minutes-v1.1703005681428.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T080000-20231108T095959-1_minutes-v1.1703005682158.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T100000-20231108T115959-1_minutes-v1.1703005682954.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T120000-20231108T135959-1_minutes-v1.1703005683687.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T140000-20231108T155959-1_minutes-v1.1703005684513.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T160000-20231108T175959-1_minutes-v1.1703005685246.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T180000-20231108T195959-1_minutes-v1.1703005686067.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T200000-20231108T215959-1_minutes-v1.1703005686888.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231108T220000-20231108T235959-1_minutes-v1.1703005687694.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T000000-20231109T015959-1_minutes-v1.1703005688447.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T020000-20231109T035959-1_minutes-v1.1703005689246.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T040000-20231109T055959-1_minutes-v1.1703005690066.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T060000-20231109T075959-1_minutes-v1.1703005691031.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T080000-20231109T095959-1_minutes-v1.1703005691788.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T100000-20231109T115959-1_minutes-v1.1703005692552.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T120000-20231109T135959-1_minutes-v1.1703005693337.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T140000-20231109T155959-1_minutes-v1.1703005694058.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T160000-20231109T175959-1_minutes-v1.1703005694842.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T180000-20231109T195959-1_minutes-v1.1703005695609.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T200000-20231109T215959-1_minutes-v1.1703005696440.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231109T220000-20231109T235959-1_minutes-v1.1703005697393.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T000000-20231110T015959-1_minutes-v1.1703005698121.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T020000-20231110T035959-1_minutes-v1.1703005698868.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T040000-20231110T055959-1_minutes-v1.1703005699691.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T060000-20231110T075959-1_minutes-v1.1703005700760.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T080000-20231110T095959-1_minutes-v1.1703005701518.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T100000-20231110T115959-1_minutes-v1.1703005702361.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T120000-20231110T135959-1_minutes-v1.1703005703145.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T140000-20231110T155959-1_minutes-v1.1703005703897.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T160000-20231110T175959-1_minutes-v1.1703005704681.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T180000-20231110T195959-1_minutes-v1.1703005705483.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T200000-20231110T215959-1_minutes-v1.1703005706364.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231110T220000-20231110T235959-1_minutes-v1.1703005707088.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T000000-20231111T015959-1_minutes-v1.1703005707864.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T020000-20231111T035959-1_minutes-v1.1703005709286.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T040000-20231111T055959-1_minutes-v1.1703005710294.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T060000-20231111T075959-1_minutes-v1.1703005711062.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T080000-20231111T095959-1_minutes-v1.1703005712159.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T100000-20231111T115959-1_minutes-v1.1703005712949.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T120000-20231111T135959-1_minutes-v1.1703005713730.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T140000-20231111T155959-1_minutes-v1.1703005714559.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T160000-20231111T175959-1_minutes-v1.1703005715329.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T180000-20231111T195959-1_minutes-v1.1703005716296.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T200000-20231111T215959-1_minutes-v1.1703005717167.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231111T220000-20231111T235959-1_minutes-v1.1703005717963.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T000000-20231112T015959-1_minutes-v1.1703005719170.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T020000-20231112T035959-1_minutes-v1.1703005719961.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T040000-20231112T055959-1_minutes-v1.1703005720720.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T060000-20231112T075959-1_minutes-v1.1703005721488.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T080000-20231112T095959-1_minutes-v1.1703005722237.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T100000-20231112T115959-1_minutes-v1.1703005723269.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T120000-20231112T135959-1_minutes-v1.1703005724539.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T140000-20231112T155959-1_minutes-v1.1703005725465.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T160000-20231112T175959-1_minutes-v1.1703005726741.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T180000-20231112T195959-1_minutes-v1.1703005727589.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T200000-20231112T215959-1_minutes-v1.1703005728497.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231112T220000-20231112T235959-1_minutes-v1.1703005729231.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T000000-20231113T015959-1_minutes-v1.1703005729997.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T020000-20231113T035959-1_minutes-v1.1703005730772.nc
# saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T040000-20231113T055959-1_minutes-v1.1703005731637.nc cannot be open. skip
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T060000-20231113T075959-1_minutes-v1.1703005732442.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T080000-20231113T095959-1_minutes-v1.1703005733455.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T100000-20231113T115959-1_minutes-v1.1703005734260.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T120000-20231113T135959-1_minutes-v1.1703005734976.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T140000-20231113T155959-1_minutes-v1.1703005735740.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T160000-20231113T175959-1_minutes-v1.1703005736460.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T180000-20231113T195959-1_minutes-v1.1703005737257.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T200000-20231113T215959-1_minutes-v1.1703005738017.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231113T220000-20231113T235959-1_minutes-v1.1703005738782.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T000000-20231114T015959-1_minutes-v1.1703005739548.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T020000-20231114T035959-1_minutes-v1.1703005740327.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T040000-20231114T055959-1_minutes-v1.1703005741154.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T060000-20231114T075959-1_minutes-v1.1703005741934.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T080000-20231114T095959-1_minutes-v1.1703005742734.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T100000-20231114T115959-1_minutes-v1.1703005743469.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T120000-20231114T135959-1_minutes-v1.1703005744539.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T140000-20231114T155959-1_minutes-v1.1703005745328.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T160000-20231114T175959-1_minutes-v1.1703005746220.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T180000-20231114T195959-1_minutes-v1.1703005747082.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T200000-20231114T215959-1_minutes-v1.1703005747867.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231114T220000-20231114T235959-1_minutes-v1.1703005748731.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T000000-20231115T015959-1_minutes-v1.1703005749664.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T020000-20231115T035959-1_minutes-v1.1703005750410.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T040000-20231115T055959-1_minutes-v1.1703005751200.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T060000-20231115T075959-1_minutes-v1.1703005751961.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T080000-20231115T095959-1_minutes-v1.1703005752851.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T100000-20231115T115959-1_minutes-v1.1703005754161.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T120000-20231115T135959-1_minutes-v1.1703005754915.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T140000-20231115T155959-1_minutes-v1.1703005755763.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T160000-20231115T175959-1_minutes-v1.1703005756586.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T180000-20231115T195959-1_minutes-v1.1703005757601.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T200000-20231115T215959-1_minutes-v1.1703005758463.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231115T220000-20231115T235959-1_minutes-v1.1703005759250.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T000000-20231116T015959-1_minutes-v1.1703005760035.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T020000-20231116T035959-1_minutes-v1.1703005760810.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T040000-20231116T055959-1_minutes-v1.1703005761653.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T060000-20231116T075959-1_minutes-v1.1703005762515.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T080000-20231116T095959-1_minutes-v1.1703005763352.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T100000-20231116T115959-1_minutes-v1.1703005764174.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T120000-20231116T135959-1_minutes-v1.1703005764935.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T140000-20231116T155959-1_minutes-v1.1703005765738.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T160000-20231116T175959-1_minutes-v1.1703005766588.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T180000-20231116T195959-1_minutes-v1.1703005767662.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T200000-20231116T215959-1_minutes-v1.1703005768623.nc
# Done saildrone-gen_6-hurricane_monitoring_2023-sd1042-20231116T220000-20231116T235959-1_minutes-v1.1703005769340.nc
# 361 can be open.
# 6 cannot be open.
# ----- Done going through nc files & append selected variables -----

# %%
for vkey in vars_yes:
    print(vkey, vars_dic[vkey].shape)
# Out:
# latitude (43320,)
# longitude (43320,)
# time (43320,)
# UWND_MEAN (43320,)
# UWND_STDDEV (43320,)
# VWND_MEAN (43320,)
# VWND_STDDEV (43320,)
# GUST_WND_MEAN (43320,)
# GUST_WND_STDDEV (43320,)
# WIND_MEASUREMENT_HEIGHT_MEAN (43320,)
# TEMP_AIR_MEAN (43320,)
# RH_MEAN (43320,)
# BARO_PRES_MEAN (43320,)
# PAR_AIR_MEAN (43320,)
# WAVE_DOMINANT_PERIOD (43320,)
# WAVE_SIGNIFICANT_HEIGHT (43320,)
# TEMP_DEPTH_HALFMETER_MEAN (43320,)
# TEMP_SBE37_MEAN (43320,)
# TEMP_SBE37_STDDEV (43320,)
# SAL_SBE37_MEAN (43320,)
# SAL_SBE37_STDDEV (43320,)
# WATER_CURRENT_SPEED_MEAN (43320,)
# WATER_CURRENT_DIRECTION_MEAN (43320,)

# %%
### plot time intervals (time(i+1)-time(i)) and print time gaps
fig, axes = plt.subplots(1)
fig.set_size_inches(22,3)
test = vars_dic['time']
dtime = np.array([datetime.datetime(1970,1,1)+datetime.timedelta(seconds= vars_dic['time'][i]) for i in range(len(vars_dic['time']))])
dtest = np.array([(test[i+1]-test[i])/3600 for i in range( len(test)-1 )]) # 
plt.semilogy(dtime[:-1],dtest)
ddays = (np.max(dtime)-np.min(dtime)).days
xticks = [np.min(dtime)+datetime.timedelta(days=5*i) for i in range(ddays)]
xtickslabel = [xticks[i].strftime('%m/%d') for i in range(ddays)]
plt.xticks(xticks)
plt.gca().set_xticklabels(xtickslabel, rotation=90)
plt.ylabel('time difference (hours)')
plt.xlim([dtime[0],dtime[-1]])
plt.grid()
print('min time difference=',np.min(dtest)*3600,'sec')
print('1st & last time in file:',dtime[0].strftime('%m/%d %H:%MZ'),dtime[-1].strftime('%m/%d %H:%MZ'))
### find data gaps
d5min = (datetime.datetime(2019,1,1,0,5,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d10min = (datetime.datetime(2019,1,1,0,10,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d30min = (datetime.datetime(2019,1,1,0,30,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d60min = (datetime.datetime(2019,1,1,1,0,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
i_tgap = np.where( dtest > d30min )[0]
print(len(i_tgap),'time gaps that are > 30 min')
print('The corresponding time gaps (in mins)',dtest[i_tgap]*60)
for i in range( len(i_tgap) ):
    print(dtime[i_tgap[i]].strftime('%m/%d %H:%MZ'),'-',dtime[i_tgap[i]+1].strftime('%m/%d %H:%MZ'))

plt.suptitle('Time intervals (t(i+1)-t(i)): Hurricane '+year+' - '+platf_num)
### save figure
fig.savefig(pathout+'time_intervals_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# min time difference= 60.0 sec
# 1st & last time in file: 08/01 00:00Z 10/23 23:59Z
# 0 time gaps that are > 30 min
# The corresponding time gaps (in mins) []

# %%
### plot merged raw wind data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['latitude','longitude','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV','WIND_MEASUREMENT_HEIGHT_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
print(vars_dic.keys())
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    if vkey in vars_dic.keys():
        print(vkey)
        data = vars_dic[vkey]
        h = plt.subplot(nrow,1,i+1)
        plt.plot(dtime,data,'.',ms=1)
        plt.xlim(tlim)
        plt.grid()
        plt.legend(h,labels=[vkey],loc='upper left')
        if i == 0:
            plt.gca().xaxis.set_ticks_position('top')
        elif i < nrow-1:
            plt.gca().set_xticklabels('')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_wind_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['time', 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude']
# dict_keys(['time', 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude'])
# latitude
# /var/folders/kq/vqqqnf_x6vd47tpg4lf57cjr0002p5/T/ipykernel_39770/3208981892.py:21: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# longitude
# UWND_MEAN
# UWND_STDDEV
# VWND_MEAN
# VWND_STDDEV
# GUST_WND_MEAN
# GUST_WND_STDDEV
# WIND_MEASUREMENT_HEIGHT_MEAN

# %%
### plot merged raw met data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN','WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT']#,\
            #  'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
            #     'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    if vkey in vars_dic.keys():
        print(vkey)
        data = vars_dic[vkey]
        h = plt.subplot(nrow,1,i+1)
        plt.plot(dtime,data,'.',ms=1)
        plt.xlim(tlim)
        plt.grid()
        plt.legend(h,labels=[vkey],loc='upper left')
        if i == 0:
            plt.gca().xaxis.set_ticks_position('top')
        elif i < nrow-1:
            plt.gca().set_xticklabels('')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_met_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['time', 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude']
# TEMP_AIR_MEAN
# RH_MEAN
# /var/folders/kq/vqqqnf_x6vd47tpg4lf57cjr0002p5/T/ipykernel_39770/687430083.py:22: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# BARO_PRES_MEAN
# PAR_AIR_MEAN
# WAVE_DOMINANT_PERIOD
# WAVE_SIGNIFICANT_HEIGHT

# %%
### plot merged raw ocean data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
             'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    if vkey in vars_dic.keys():
        print(vkey)
        data = vars_dic[vkey]
        h = plt.subplot(nrow,1,i+1)
        plt.plot(dtime,data,'.',ms=1)
        plt.xlim(tlim)
        plt.grid()
        plt.legend(h,labels=[vkey],loc='upper left')
        if i == 0:
            plt.gca().xaxis.set_ticks_position('top')
        elif i < nrow-1:
            plt.gca().set_xticklabels('')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_sea_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['time', 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude']
# TEMP_DEPTH_HALFMETER_MEAN
# TEMP_SBE37_MEAN
# /var/folders/kq/vqqqnf_x6vd47tpg4lf57cjr0002p5/T/ipykernel_39770/2582502085.py:21: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# TEMP_SBE37_STDDEV
# SAL_SBE37_MEAN
# SAL_SBE37_STDDEV
# WATER_CURRENT_SPEED_MEAN
# WATER_CURRENT_DIRECTION_MEAN

# %%
### write the merged data to netcdf file: https://unidata.github.io/python-training/workshop/Bonus/netcdf-writing/
try: ncfile.close()  # just to be safe, make sure dataset is not already open.
except: pass
ncfname_out = 'airsea-raw-merge-'+year+'-SD'+platf_num+'.nc'
ncfile = nc.Dataset(ncfname_out,mode='w',format='NETCDF4_CLASSIC') 
print(ncfile)
### creating dimensions
time_dim = ncfile.createDimension('time', len(dtime)) # unlimited axis (can be appended to).
for dim in ncfile.dimensions.items():
    print(dim)
### creating attributes
ncfile.title='Merged files for '+year+' SD-'+platf_num
print(ncfile.title)
ncfile.subtitle="Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute."
print(ncfile.subtitle)
print(ncfile)
### move the writing data to new variables
### compute the time as seconds since 2022-01-01
time_out = np.array([(dtime[i]-datetime.datetime(int(year),1,1)).total_seconds() for i in range(len(dtime))])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# ('time', <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 120960)
# Merged files for 2023 SD-1031
# Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: Merged files for 2023 SD-1031
#     subtitle: Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
#     dimensions(sizes): time(120960)
#     variables(dimensions):
#     groups:

# %%
def isMonotonic(A):
    return (all(A[i] <= A[i + 1] for i in range(len(A) - 1)) or
            all(A[i] >= A[i + 1] for i in range(len(A) - 1)))
print('is time_out monotonic? -->', isMonotonic(time_out))

plt.subplot(3,1,1)
plt.plot(time_out,'.')
plt.subplot(3,1,2)
plt.semilogy(np.diff(np.sort(time_out)),'.')
plt.grid()
plt.subplot(3,1,3)
plt.hist(np.diff(np.sort(time_out)))
# Out:
# is time_out monotonic? --> True
# (array([     0.,      0.,      0.,      0.,      0., 120959.,      0.,
#              0.,      0.,      0.]),
#  array([59.5, 59.6, 59.7, 59.8, 59.9, 60. , 60.1, 60.2, 60.3, 60.4, 60.5]),
#  <BarContainer object of 10 artists>)

# %%
### Creating variables: 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN'
time = ncfile.createVariable('time', np.float64, ('time',))
time.units = 'seconds since '+year+'-01-01'
time.long_name = 'time'
### 1D variables
# vars_yes = ['latitude','longitude','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV',\
#             'WIND_MEASUREMENT_HEIGHT_MEAN','TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN',\
#                 'WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT',\
#                     'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
#                         'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
### 1: (time,)
vkey_attr = vars_dic_attr.keys()
for vkey in vars_dic.keys():
    if vkey != 'time':
        ### create variables
        str_exec = vkey + "= ncfile.createVariable('" + vkey + "', np.float64, ('" + 'time' + "',))"
        print(str_exec)
        exec(str_exec)
        # print(i,str_exec)
        vkey_attr_4_this_vkey = [x for x in vkey_attr if vkey in x]
        ### add attributes
        for a in vkey_attr_4_this_vkey:
            ind_ = a.find('-')
            attr_this_round = a[ind_+1:]
            # if attr[a] in attr_in_vkey: # if attribute of this vkey exist, write out
            #     if (attr[a] == 'installed_height') & (vkey in vars_no_installed_height):
            #         pass
            #     else:
            str_exec = vkey + "."+ attr_this_round + " = '"+ str( vars_dic_attr[a] ) + "'"
            exec(str_exec)
            print(a,str_exec)
# Out:
# UWND_MEAN= ncfile.createVariable('UWND_MEAN', np.float64, ('time',))
# UWND_MEAN-long_name UWND_MEAN.long_name = 'Eastward wind speed'
# UWND_MEAN-units UWND_MEAN.units = 'm s-1'
# UWND_MEAN-installed_height UWND_MEAN.installed_height = '5.2'
# UWND_STDDEV= ncfile.createVariable('UWND_STDDEV', np.float64, ('time',))
# UWND_STDDEV-long_name UWND_STDDEV.long_name = 'Eastward wind speed SD'
# UWND_STDDEV-units UWND_STDDEV.units = 'm s-1'
# UWND_STDDEV-installed_height UWND_STDDEV.installed_height = '5.2'
# VWND_MEAN= ncfile.createVariable('VWND_MEAN', np.float64, ('time',))
# VWND_MEAN-long_name VWND_MEAN.long_name = 'Northward wind speed'
# VWND_MEAN-units VWND_MEAN.units = 'm s-1'
# VWND_MEAN-installed_height VWND_MEAN.installed_height = '5.2'
# VWND_STDDEV= ncfile.createVariable('VWND_STDDEV', np.float64, ('time',))
# VWND_STDDEV-long_name VWND_STDDEV.long_name = 'Northward wind speed SD'
# VWND_STDDEV-units VWND_STDDEV.units = 'm s-1'
# VWND_STDDEV-installed_height VWND_STDDEV.installed_height = '5.2'
# GUST_WND_MEAN= ncfile.createVariable('GUST_WND_MEAN', np.float64, ('time',))
# GUST_WND_MEAN-long_name GUST_WND_MEAN.long_name = 'Wind gust speed'
# GUST_WND_MEAN-units GUST_WND_MEAN.units = 'm s-1'
# GUST_WND_MEAN-installed_height GUST_WND_MEAN.installed_height = '5.2'
# GUST_WND_STDDEV= ncfile.createVariable('GUST_WND_STDDEV', np.float64, ('time',))
# GUST_WND_STDDEV-long_name GUST_WND_STDDEV.long_name = 'Wind gust speed SD'
# GUST_WND_STDDEV-units GUST_WND_STDDEV.units = 'm s-1'
# GUST_WND_STDDEV-installed_height GUST_WND_STDDEV.installed_height = '5.2'
# WIND_MEASUREMENT_HEIGHT_MEAN= ncfile.createVariable('WIND_MEASUREMENT_HEIGHT_MEAN', np.float64, ('time',))
# WIND_MEASUREMENT_HEIGHT_MEAN-long_name WIND_MEASUREMENT_HEIGHT_MEAN.long_name = 'Wind measurement height'
# WIND_MEASUREMENT_HEIGHT_MEAN-units WIND_MEASUREMENT_HEIGHT_MEAN.units = 'm'
# WIND_MEASUREMENT_HEIGHT_MEAN-installed_height WIND_MEASUREMENT_HEIGHT_MEAN.installed_height = '5.2'
# TEMP_AIR_MEAN= ncfile.createVariable('TEMP_AIR_MEAN', np.float64, ('time',))
# TEMP_AIR_MEAN-long_name TEMP_AIR_MEAN.long_name = 'Air temperature'
# TEMP_AIR_MEAN-units TEMP_AIR_MEAN.units = 'degrees_c'
# TEMP_AIR_MEAN-installed_height TEMP_AIR_MEAN.installed_height = '2.3'
# RH_MEAN= ncfile.createVariable('RH_MEAN', np.float64, ('time',))
# RH_MEAN-long_name RH_MEAN.long_name = 'Relative humidity'
# RH_MEAN-units RH_MEAN.units = 'percent'
# RH_MEAN-installed_height RH_MEAN.installed_height = '2.3'
# BARO_PRES_MEAN= ncfile.createVariable('BARO_PRES_MEAN', np.float64, ('time',))
# BARO_PRES_MEAN-long_name BARO_PRES_MEAN.long_name = 'Air pressure'
# BARO_PRES_MEAN-units BARO_PRES_MEAN.units = 'hPa'
# BARO_PRES_MEAN-installed_height BARO_PRES_MEAN.installed_height = '0.2'
# PAR_AIR_MEAN= ncfile.createVariable('PAR_AIR_MEAN', np.float64, ('time',))
# PAR_AIR_MEAN-long_name PAR_AIR_MEAN.long_name = 'Photosynthetically active radiation in air'
# PAR_AIR_MEAN-units PAR_AIR_MEAN.units = 'micromol s-1 m-2'
# PAR_AIR_MEAN-installed_height PAR_AIR_MEAN.installed_height = '2.6'
# WAVE_DOMINANT_PERIOD= ncfile.createVariable('WAVE_DOMINANT_PERIOD', np.float64, ('time',))
# WAVE_DOMINANT_PERIOD-long_name WAVE_DOMINANT_PERIOD.long_name = 'Dominant wave period'
# WAVE_DOMINANT_PERIOD-units WAVE_DOMINANT_PERIOD.units = 's'
# WAVE_DOMINANT_PERIOD-installed_height WAVE_DOMINANT_PERIOD.installed_height = '0.34'
# WAVE_SIGNIFICANT_HEIGHT= ncfile.createVariable('WAVE_SIGNIFICANT_HEIGHT', np.float64, ('time',))
# WAVE_SIGNIFICANT_HEIGHT-long_name WAVE_SIGNIFICANT_HEIGHT.long_name = 'Significant wave height'
# WAVE_SIGNIFICANT_HEIGHT-units WAVE_SIGNIFICANT_HEIGHT.units = 'm'
# WAVE_SIGNIFICANT_HEIGHT-installed_height WAVE_SIGNIFICANT_HEIGHT.installed_height = '0.34'
# TEMP_DEPTH_HALFMETER_MEAN= ncfile.createVariable('TEMP_DEPTH_HALFMETER_MEAN', np.float64, ('time',))
# TEMP_DEPTH_HALFMETER_MEAN-long_name TEMP_DEPTH_HALFMETER_MEAN.long_name = 'Seawater temperature at depth of 0.5m'
# TEMP_DEPTH_HALFMETER_MEAN-units TEMP_DEPTH_HALFMETER_MEAN.units = 'degrees_c'
# TEMP_DEPTH_HALFMETER_MEAN-installed_height TEMP_DEPTH_HALFMETER_MEAN.installed_height = '-0.5'
# TEMP_SBE37_MEAN= ncfile.createVariable('TEMP_SBE37_MEAN', np.float64, ('time',))
# TEMP_SBE37_MEAN-long_name TEMP_SBE37_MEAN.long_name = 'Seawater temperature'
# TEMP_SBE37_MEAN-units TEMP_SBE37_MEAN.units = 'degrees_c'
# TEMP_SBE37_MEAN-installed_height TEMP_SBE37_MEAN.installed_height = '-1.7'
# TEMP_SBE37_STDDEV= ncfile.createVariable('TEMP_SBE37_STDDEV', np.float64, ('time',))
# TEMP_SBE37_STDDEV-long_name TEMP_SBE37_STDDEV.long_name = 'Seawater temperature SD'
# TEMP_SBE37_STDDEV-units TEMP_SBE37_STDDEV.units = 'degrees_c'
# TEMP_SBE37_STDDEV-installed_height TEMP_SBE37_STDDEV.installed_height = '-1.7'
# SAL_SBE37_MEAN= ncfile.createVariable('SAL_SBE37_MEAN', np.float64, ('time',))
# SAL_SBE37_MEAN-long_name SAL_SBE37_MEAN.long_name = 'Seawater salinity'
# SAL_SBE37_MEAN-units SAL_SBE37_MEAN.units = '1'
# SAL_SBE37_MEAN-installed_height SAL_SBE37_MEAN.installed_height = '-1.7'
# SAL_SBE37_STDDEV= ncfile.createVariable('SAL_SBE37_STDDEV', np.float64, ('time',))
# SAL_SBE37_STDDEV-long_name SAL_SBE37_STDDEV.long_name = 'Seawater salinity SD'
# SAL_SBE37_STDDEV-units SAL_SBE37_STDDEV.units = '1'
# SAL_SBE37_STDDEV-installed_height SAL_SBE37_STDDEV.installed_height = '-1.7'
# WATER_CURRENT_SPEED_MEAN= ncfile.createVariable('WATER_CURRENT_SPEED_MEAN', np.float64, ('time',))
# WATER_CURRENT_SPEED_MEAN-long_name WATER_CURRENT_SPEED_MEAN.long_name = 'Water Current Speed'
# WATER_CURRENT_SPEED_MEAN-units WATER_CURRENT_SPEED_MEAN.units = 'm s-1'
# WATER_CURRENT_SPEED_MEAN-installed_height WATER_CURRENT_SPEED_MEAN.installed_height = '-1.9'
# WATER_CURRENT_DIRECTION_MEAN= ncfile.createVariable('WATER_CURRENT_DIRECTION_MEAN', np.float64, ('time',))
# WATER_CURRENT_DIRECTION_MEAN-long_name WATER_CURRENT_DIRECTION_MEAN.long_name = 'Water Current Direction'
# WATER_CURRENT_DIRECTION_MEAN-units WATER_CURRENT_DIRECTION_MEAN.units = 'degree'
# WATER_CURRENT_DIRECTION_MEAN-installed_height WATER_CURRENT_DIRECTION_MEAN.installed_height = '-1.9'
# latitude= ncfile.createVariable('latitude', np.float64, ('time',))
# latitude-long_name latitude.long_name = 'Latitude'
# latitude-units latitude.units = 'degrees_north'
# longitude= ncfile.createVariable('longitude', np.float64, ('time',))
# longitude-long_name longitude.long_name = 'Longitude'
# longitude-units longitude.units = 'degrees_east'

# %%
print(vkey_attr_4_this_vkey)
# Out:
# ['longitude-long_name', 'longitude-units']

# %%
### writing data
# Note: the ":" is necessary in these "write" statements
time[:] = time_out
for vkey in vars_dic.keys():
    if vkey != 'time':
        str_exec = vkey + "[:]= vars_dic['" + vkey + "']"
        exec(str_exec)    
print(ncfile)
# close the Dataset.
ncfile.close(); print('Dataset is closed!')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: Merged files for 2023 SD-1031
#     subtitle: Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
#     dimensions(sizes): time(120960)
#     variables(dimensions): float64 time(time), float64 UWND_MEAN(time), float64 UWND_STDDEV(time), float64 VWND_MEAN(time), float64 VWND_STDDEV(time), float64 GUST_WND_MEAN(time), float64 GUST_WND_STDDEV(time), float64 WIND_MEASUREMENT_HEIGHT_MEAN(time), float64 TEMP_AIR_MEAN(time), float64 RH_MEAN(time), float64 BARO_PRES_MEAN(time), float64 PAR_AIR_MEAN(time), float64 WAVE_DOMINANT_PERIOD(time), float64 WAVE_SIGNIFICANT_HEIGHT(time), float64 TEMP_DEPTH_HALFMETER_MEAN(time), float64 TEMP_SBE37_MEAN(time), float64 TEMP_SBE37_STDDEV(time), float64 SAL_SBE37_MEAN(time), float64 SAL_SBE37_STDDEV(time), float64 WATER_CURRENT_SPEED_MEAN(time), float64 WATER_CURRENT_DIRECTION_MEAN(time), float64 latitude(time), float64 longitude(time)
#     groups:
# Dataset is closed!
