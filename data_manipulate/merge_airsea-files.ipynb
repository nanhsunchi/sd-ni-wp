# %%
### Merge wind 1-min files
import numpy as np
import netCDF4 as nc
import matplotlib
import matplotlib.pyplot as plt
import datetime
import os
import math
import cftime
import sys
path_nhchi = os.path.expanduser('~/Documents/projects/analytical-tools/py_nhchi/')
# adding to the system path
sys.path.insert(0, path_nhchi)
# from read_topo import load_topo_arctic_HiRes, load_topo_arctic
from convert_time import datetime_to_yearday
# Importing saildrone data:
year = '2022'
platf_num = '1031'
path = os.path.expanduser('~/Documents/Data/Hurricane'+year+'/delayed/'+platf_num+'/')
outpath = path+'merged_files/'
filenames = np.sort( os.listdir(path) ); print('has',len(filenames),'files in the directory')
filenames = [x for x in filenames if ".nc" in x]; print('has',len(filenames),'nc files')
pathout = os.getcwd()+'/fig_'+platf_num+'/'
print(pathout)
if os.path.isdir(pathout):
    pass
else:
    os.mkdir(pathout)
### the list of variables I want
vars_yes = ['latitude','longitude','time','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV',\
            'WIND_MEASUREMENT_HEIGHT_MEAN','TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN',\
                'WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT',\
                    'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
                        'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
# Out:
# has 1286 files in the directory
# has 1285 nc files
# /Users/chi/Documents/projects/sd-windpower/plot_SD/fig_1031/

# %%
### create a dictionary
vars_dic = {}
vars_dic_attr = {}
attr = ['long_name','units','installed_height']
vars_no_installed_height = ['latitude','longitude','time']
ds = nc.Dataset(path+'/'+filenames[0])
# nz = len( ds.variables['cell_depth'][:] )
varnms = list( ds.variables.keys() )
### add empty items to the dictionary 
for i in range( len(varnms) ):
    vkey = varnms[i]
    if vkey in vars_yes:
        item = ds.variables[vkey][:]
        vars_dic[vkey] = np.empty( item.shape )
        ### record attributes
        for a in range( len(attr) ):
            if (attr[a] == 'installed_height') & (vkey in vars_no_installed_height):
                pass
            else:
                str_eval = "ds.variables['" + vkey + "']." + attr[a]
                vars_dic_attr[vkey+'-'+attr[a]] = eval(str_eval)
        # print(vkey, item.shape, vars_dic[vkey].shape)
print(len(varnms),'variables in nc file &', len(vars_dic),'variables are selected to append')
### go through each daily nc file & append the selected variables 
for f in range( len(filenames) ):
    fsize = os.stat(path+'/'+filenames[f]).st_size/1000 # kb
    if fsize > 400:
        ds = nc.Dataset(path+'/'+filenames[f])
        for i in range( len(varnms) ):
            vkey = varnms[i]
            if (vkey in vars_yes): #& (vkey not in vars_nostack):
                # print(vkey)
                vkey = varnms[i]
                item_old = vars_dic[vkey]
                item_app = np.squeeze( ds.variables[vkey][:] )
                ### append in time dimension only
                if f == 0:
                    vars_dic[vkey] = item_app
                else:
                    vars_dic[vkey] = np.concatenate( (item_old, item_app),axis=0 )
        print('Done',filenames[f])
    else:
        print(filenames[f],'filesize too small. skipped')
# Out:
# 77 variables in nc file & 23 variables are selected to append
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220715T200000-20220715T215959-1_minutes-v1.1658010635687.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220715T220000-20220715T235959-1_minutes-v1.1658017880133.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T000000-20220716T015959-1_minutes-v1.1658025018031.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T020000-20220716T035959-1_minutes-v1.1658032228459.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T040000-20220716T055959-1_minutes-v1.1658039480901.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T060000-20220716T075959-1_minutes-v1.1658046609972.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T080000-20220716T095959-1_minutes-v1.1658053904633.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T100000-20220716T115959-1_minutes-v1.1658061026234.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T120000-20220716T135959-1_minutes-v1.1658068249117.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T140000-20220716T155959-1_minutes-v1.1658075427326.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T160000-20220716T175959-1_minutes-v1.1658082653241.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T180000-20220716T195959-1_minutes-v1.1658089839913.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T200000-20220716T215959-1_minutes-v1.1658097013911.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220716T220000-20220716T235959-1_minutes-v1.1658104324959.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T000000-20220717T015959-1_minutes-v1.1658111466487.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T020000-20220717T035959-1_minutes-v1.1658118663321.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T040000-20220717T055959-1_minutes-v1.1658125804262.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T060000-20220717T075959-1_minutes-v1.1658133019952.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T080000-20220717T095959-1_minutes-v1.1658140320216.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T100000-20220717T115959-1_minutes-v1.1658147419796.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T120000-20220717T135959-1_minutes-v1.1658154604994.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T140000-20220717T155959-1_minutes-v1.1658161965394.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T160000-20220717T175959-1_minutes-v1.1658169004473.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T180000-20220717T195959-1_minutes-v1.1658176215656.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T200000-20220717T215959-1_minutes-v1.1658183435140.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220717T220000-20220717T235959-1_minutes-v1.1658190685453.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T000000-20220718T015959-1_minutes-v1.1658197861172.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T020000-20220718T035959-1_minutes-v1.1658205004820.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T040000-20220718T055959-1_minutes-v1.1658212228721.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T060000-20220718T075959-1_minutes-v1.1658219457614.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T080000-20220718T095959-1_minutes-v1.1658226617967.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T100000-20220718T115959-1_minutes-v1.1658233820413.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T120000-20220718T135959-1_minutes-v1.1658241108306.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T140000-20220718T155959-1_minutes-v1.1658248279448.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T160000-20220718T175959-1_minutes-v1.1658255510748.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T180000-20220718T195959-1_minutes-v1.1658262672823.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T200000-20220718T215959-1_minutes-v1.1658269840294.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220718T220000-20220718T235959-1_minutes-v1.1658277099888.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T000000-20220719T015959-1_minutes-v1.1658284240772.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T020000-20220719T035959-1_minutes-v1.1658291424637.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T040000-20220719T055959-1_minutes-v1.1658298645336.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T060000-20220719T075959-1_minutes-v1.1658305859991.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T080000-20220719T095959-1_minutes-v1.1658313059969.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T100000-20220719T115959-1_minutes-v1.1658320263256.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T120000-20220719T135959-1_minutes-v1.1658327460477.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T140000-20220719T155959-1_minutes-v1.1658334635028.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T160000-20220719T175959-1_minutes-v1.1658341840317.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T180000-20220719T195959-1_minutes-v1.1658349075513.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T200000-20220719T215959-1_minutes-v1.1658356276036.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220719T220000-20220719T235959-1_minutes-v1.1658363438117.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T000000-20220720T015959-1_minutes-v1.1658370676794.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T020000-20220720T035959-1_minutes-v1.1658377820826.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T040000-20220720T055959-1_minutes-v1.1658385018639.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T060000-20220720T075959-1_minutes-v1.1658392214845.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T080000-20220720T095959-1_minutes-v1.1658399430254.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T100000-20220720T115959-1_minutes-v1.1658406634925.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T120000-20220720T135959-1_minutes-v1.1658413825678.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T140000-20220720T155959-1_minutes-v1.1658421020691.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T160000-20220720T175959-1_minutes-v1.1658428230680.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T180000-20220720T195959-1_minutes-v1.1658435412714.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T200000-20220720T215959-1_minutes-v1.1658442635688.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220720T220000-20220720T235959-1_minutes-v1.1658449909864.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T000000-20220721T015959-1_minutes-v1.1658457003912.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T020000-20220721T035959-1_minutes-v1.1658464241170.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T040000-20220721T055959-1_minutes-v1.1658471475876.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T060000-20220721T075959-1_minutes-v1.1658478679826.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T080000-20220721T095959-1_minutes-v1.1658485895975.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T100000-20220721T115959-1_minutes-v1.1658493035041.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T120000-20220721T135959-1_minutes-v1.1658500268208.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T140000-20220721T155959-1_minutes-v1.1658507410202.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T160000-20220721T175959-1_minutes-v1.1658514640276.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T180000-20220721T195959-1_minutes-v1.1658521835900.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T200000-20220721T215959-1_minutes-v1.1658529040606.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220721T220000-20220721T235959-1_minutes-v1.1658536345178.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T000000-20220722T015959-1_minutes-v1.1658543480206.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T020000-20220722T035959-1_minutes-v1.1658550624837.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T040000-20220722T055959-1_minutes-v1.1658557834163.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T060000-20220722T075959-1_minutes-v1.1658565030697.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T080000-20220722T095959-1_minutes-v1.1658572204550.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T100000-20220722T115959-1_minutes-v1.1658579419860.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T120000-20220722T135959-1_minutes-v1.1658586605213.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T140000-20220722T155959-1_minutes-v1.1658593888107.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T160000-20220722T175959-1_minutes-v1.1658601060325.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T180000-20220722T195959-1_minutes-v1.1658608254357.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T200000-20220722T215959-1_minutes-v1.1658615426001.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220722T220000-20220722T235959-1_minutes-v1.1658622605159.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T000000-20220723T015959-1_minutes-v1.1658629840096.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T020000-20220723T035959-1_minutes-v1.1658637110583.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T040000-20220723T055959-1_minutes-v1.1658644238724.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T060000-20220723T075959-1_minutes-v1.1658651458064.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T080000-20220723T095959-1_minutes-v1.1658658623592.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T100000-20220723T115959-1_minutes-v1.1658665805721.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T120000-20220723T135959-1_minutes-v1.1658673025525.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T140000-20220723T155959-1_minutes-v1.1658680217659.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T160000-20220723T175959-1_minutes-v1.1658687424011.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T180000-20220723T195959-1_minutes-v1.1658694625351.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T200000-20220723T215959-1_minutes-v1.1658701878732.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220723T220000-20220723T235959-1_minutes-v1.1658709079992.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T000000-20220724T015959-1_minutes-v1.1658716300911.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T020000-20220724T035959-1_minutes-v1.1658723432694.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T040000-20220724T055959-1_minutes-v1.1658730634481.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T060000-20220724T075959-1_minutes-v1.1658737860318.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T080000-20220724T095959-1_minutes-v1.1658745050491.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T100000-20220724T115959-1_minutes-v1.1658752258112.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T120000-20220724T135959-1_minutes-v1.1658759404352.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T140000-20220724T155959-1_minutes-v1.1658766622582.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T160000-20220724T175959-1_minutes-v1.1658773847598.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T180000-20220724T195959-1_minutes-v1.1658781013729.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T200000-20220724T215959-1_minutes-v1.1658788209880.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220724T220000-20220724T235959-1_minutes-v1.1658795564089.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T000000-20220725T015959-1_minutes-v1.1658802627893.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T020000-20220725T035959-1_minutes-v1.1658809810163.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T040000-20220725T055959-1_minutes-v1.1658817013357.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T060000-20220725T075959-1_minutes-v1.1658824205551.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T080000-20220725T095959-1_minutes-v1.1658831425402.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T100000-20220725T115959-1_minutes-v1.1658838752061.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T120000-20220725T135959-1_minutes-v1.1658845880475.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T140000-20220725T155959-1_minutes-v1.1658853013235.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T160000-20220725T175959-1_minutes-v1.1658860223291.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T180000-20220725T195959-1_minutes-v1.1658867526515.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T200000-20220725T215959-1_minutes-v1.1658874640096.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220725T220000-20220725T235959-1_minutes-v1.1658881855102.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T000000-20220726T015959-1_minutes-v1.1658889014336.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T020000-20220726T035959-1_minutes-v1.1658896243085.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T040000-20220726T055959-1_minutes-v1.1658903405244.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T060000-20220726T075959-1_minutes-v1.1658910620186.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T080000-20220726T095959-1_minutes-v1.1658917812838.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T100000-20220726T115959-1_minutes-v1.1658925030080.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T120000-20220726T135959-1_minutes-v1.1658932224048.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T140000-20220726T155959-1_minutes-v1.1658939420919.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T160000-20220726T175959-1_minutes-v1.1658946625175.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T180000-20220726T195959-1_minutes-v1.1658953809858.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T200000-20220726T215959-1_minutes-v1.1658961055180.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220726T220000-20220726T235959-1_minutes-v1.1658968214153.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T000000-20220727T015959-1_minutes-v1.1658975466236.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T020000-20220727T035959-1_minutes-v1.1658982632568.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T040000-20220727T055959-1_minutes-v1.1658989805439.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T060000-20220727T075959-1_minutes-v1.1658997050189.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T080000-20220727T095959-1_minutes-v1.1659004309492.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T100000-20220727T115959-1_minutes-v1.1659011464694.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T120000-20220727T135959-1_minutes-v1.1659018604933.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T140000-20220727T155959-1_minutes-v1.1659025830722.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T160000-20220727T175959-1_minutes-v1.1659033049803.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T180000-20220727T195959-1_minutes-v1.1659040249832.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T200000-20220727T215959-1_minutes-v1.1659047433921.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220727T220000-20220727T235959-1_minutes-v1.1659054669936.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T000000-20220728T015959-1_minutes-v1.1659061865781.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T020000-20220728T035959-1_minutes-v1.1659069091033.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T040000-20220728T055959-1_minutes-v1.1659076225038.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T060000-20220728T075959-1_minutes-v1.1659083450713.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T080000-20220728T095959-1_minutes-v1.1659090680325.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T100000-20220728T115959-1_minutes-v1.1659097910883.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T120000-20220728T135959-1_minutes-v1.1659105026126.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T140000-20220728T155959-1_minutes-v1.1659112244963.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T160000-20220728T175959-1_minutes-v1.1659119410064.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T180000-20220728T195959-1_minutes-v1.1659126625555.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T200000-20220728T215959-1_minutes-v1.1659133817626.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220728T220000-20220728T235959-1_minutes-v1.1659141003847.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T000000-20220729T015959-1_minutes-v1.1659148210102.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T020000-20220729T035959-1_minutes-v1.1659155420115.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T040000-20220729T055959-1_minutes-v1.1659162680363.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T060000-20220729T075959-1_minutes-v1.1659169829305.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T080000-20220729T095959-1_minutes-v1.1659177015366.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T100000-20220729T115959-1_minutes-v1.1659184224787.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T120000-20220729T135959-1_minutes-v1.1659191470463.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T140000-20220729T155959-1_minutes-v1.1659198648005.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T160000-20220729T175959-1_minutes-v1.1659205910702.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T180000-20220729T195959-1_minutes-v1.1659213074771.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T200000-20220729T215959-1_minutes-v1.1659220254683.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220729T220000-20220729T235959-1_minutes-v1.1659227452324.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T000000-20220730T015959-1_minutes-v1.1659234604701.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T020000-20220730T035959-1_minutes-v1.1659241817463.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T040000-20220730T055959-1_minutes-v1.1659249029646.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T060000-20220730T075959-1_minutes-v1.1659256223868.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T080000-20220730T095959-1_minutes-v1.1659263434921.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T100000-20220730T115959-1_minutes-v1.1659270610190.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T120000-20220730T135959-1_minutes-v1.1659277890392.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T140000-20220730T155959-1_minutes-v1.1659285090097.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T160000-20220730T175959-1_minutes-v1.1659292252864.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T180000-20220730T195959-1_minutes-v1.1659299415066.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T200000-20220730T215959-1_minutes-v1.1659306610257.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220730T220000-20220730T235959-1_minutes-v1.1659313980803.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T000000-20220731T015959-1_minutes-v1.1659321044653.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T020000-20220731T035959-1_minutes-v1.1659328310812.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T040000-20220731T055959-1_minutes-v1.1659335489934.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T060000-20220731T075959-1_minutes-v1.1659342640313.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T080000-20220731T095959-1_minutes-v1.1659349879782.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T100000-20220731T115959-1_minutes-v1.1659357037838.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T120000-20220731T135959-1_minutes-v1.1659364277408.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T140000-20220731T155959-1_minutes-v1.1659371495724.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T160000-20220731T175959-1_minutes-v1.1659378675448.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T180000-20220731T195959-1_minutes-v1.1659385804214.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T200000-20220731T215959-1_minutes-v1.1659393028536.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220731T220000-20220731T235959-1_minutes-v1.1659400425370.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T000000-20220801T015959-1_minutes-v1.1659407442959.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T020000-20220801T035959-1_minutes-v1.1659414635211.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T040000-20220801T055959-1_minutes-v1.1659421875224.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T060000-20220801T075959-1_minutes-v1.1659429102817.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T080000-20220801T095959-1_minutes-v1.1659436204582.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T100000-20220801T115959-1_minutes-v1.1659443419995.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T120000-20220801T135959-1_minutes-v1.1659450629900.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T140000-20220801T155959-1_minutes-v1.1659457833874.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T160000-20220801T175959-1_minutes-v1.1659465150430.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T180000-20220801T195959-1_minutes-v1.1659472215525.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T200000-20220801T215959-1_minutes-v1.1659479420284.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220801T220000-20220801T235959-1_minutes-v1.1659486637620.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T000000-20220802T015959-1_minutes-v1.1659493808507.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T020000-20220802T035959-1_minutes-v1.1659501015416.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T040000-20220802T055959-1_minutes-v1.1659508290376.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T060000-20220802T075959-1_minutes-v1.1659515435176.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T080000-20220802T095959-1_minutes-v1.1659522624551.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T100000-20220802T115959-1_minutes-v1.1659529854952.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T120000-20220802T135959-1_minutes-v1.1659537055490.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T140000-20220802T155959-1_minutes-v1.1659544225481.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T160000-20220802T175959-1_minutes-v1.1659551414698.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T180000-20220802T195959-1_minutes-v1.1659558633269.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T200000-20220802T215959-1_minutes-v1.1659565860129.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220802T220000-20220802T235959-1_minutes-v1.1659573070107.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T000000-20220803T015959-1_minutes-v1.1659580244962.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T020000-20220803T035959-1_minutes-v1.1659587434795.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T040000-20220803T055959-1_minutes-v1.1659594615505.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T060000-20220803T075959-1_minutes-v1.1659601805752.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T080000-20220803T095959-1_minutes-v1.1659609083180.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T100000-20220803T115959-1_minutes-v1.1659616338191.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T120000-20220803T135959-1_minutes-v1.1659623465260.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T140000-20220803T155959-1_minutes-v1.1659630635218.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T160000-20220803T175959-1_minutes-v1.1659637820177.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T180000-20220803T195959-1_minutes-v1.1659645114921.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T200000-20220803T215959-1_minutes-v1.1659652280683.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220803T220000-20220803T235959-1_minutes-v1.1659659502545.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T000000-20220804T015959-1_minutes-v1.1659666610388.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T020000-20220804T035959-1_minutes-v1.1659673845746.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T040000-20220804T055959-1_minutes-v1.1659681071093.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T060000-20220804T075959-1_minutes-v1.1659688300521.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T080000-20220804T095959-1_minutes-v1.1659695469596.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T100000-20220804T115959-1_minutes-v1.1659702655539.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T120000-20220804T135959-1_minutes-v1.1659709900195.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T140000-20220804T155959-1_minutes-v1.1659717013262.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T160000-20220804T175959-1_minutes-v1.1659724270804.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T180000-20220804T195959-1_minutes-v1.1659731424431.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T200000-20220804T215959-1_minutes-v1.1659738705459.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220804T220000-20220804T235959-1_minutes-v1.1659746030657.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T000000-20220805T015959-1_minutes-v1.1659753004130.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T020000-20220805T035959-1_minutes-v1.1659760244006.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T040000-20220805T055959-1_minutes-v1.1659767430147.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T060000-20220805T075959-1_minutes-v1.1659774640377.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T080000-20220805T095959-1_minutes-v1.1659781860152.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T100000-20220805T115959-1_minutes-v1.1659789005460.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T120000-20220805T135959-1_minutes-v1.1659796285488.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T140000-20220805T155959-1_minutes-v1.1659803449865.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T160000-20220805T175959-1_minutes-v1.1659810639739.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T180000-20220805T195959-1_minutes-v1.1659817813375.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T200000-20220805T215959-1_minutes-v1.1659825025561.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220805T220000-20220805T235959-1_minutes-v1.1659832295142.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T000000-20220806T015959-1_minutes-v1.1659839436150.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T020000-20220806T035959-1_minutes-v1.1659846652318.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T040000-20220806T055959-1_minutes-v1.1659853803894.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T060000-20220806T075959-1_minutes-v1.1659861039698.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T080000-20220806T095959-1_minutes-v1.1659868225027.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T100000-20220806T115959-1_minutes-v1.1659875475203.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T120000-20220806T135959-1_minutes-v1.1659882709256.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T140000-20220806T155959-1_minutes-v1.1659889912736.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T160000-20220806T175959-1_minutes-v1.1659897071026.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T180000-20220806T195959-1_minutes-v1.1659904212599.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T200000-20220806T215959-1_minutes-v1.1659911457395.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220806T220000-20220806T235959-1_minutes-v1.1659918715138.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T000000-20220807T015959-1_minutes-v1.1659925886049.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T020000-20220807T035959-1_minutes-v1.1659933097729.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T040000-20220807T055959-1_minutes-v1.1659940255399.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T060000-20220807T075959-1_minutes-v1.1659947421226.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T080000-20220807T095959-1_minutes-v1.1659954607850.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T100000-20220807T115959-1_minutes-v1.1659961823221.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T120000-20220807T135959-1_minutes-v1.1659969019249.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T140000-20220807T155959-1_minutes-v1.1659976220387.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T160000-20220807T175959-1_minutes-v1.1659983472970.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T180000-20220807T195959-1_minutes-v1.1659990722750.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T200000-20220807T215959-1_minutes-v1.1659997810420.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220807T220000-20220807T235959-1_minutes-v1.1660005175646.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T000000-20220808T015959-1_minutes-v1.1660012255253.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T020000-20220808T035959-1_minutes-v1.1660019403656.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T040000-20220808T055959-1_minutes-v1.1660026660480.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T060000-20220808T075959-1_minutes-v1.1660033855361.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T080000-20220808T095959-1_minutes-v1.1660041054963.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T100000-20220808T115959-1_minutes-v1.1660048294986.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T120000-20220808T135959-1_minutes-v1.1660055478236.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T140000-20220808T155959-1_minutes-v1.1660062685756.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T160000-20220808T175959-1_minutes-v1.1660069825429.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T180000-20220808T195959-1_minutes-v1.1660077100329.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T200000-20220808T215959-1_minutes-v1.1660084268308.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220808T220000-20220808T235959-1_minutes-v1.1660091552680.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T000000-20220809T015959-1_minutes-v1.1660098722696.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T020000-20220809T035959-1_minutes-v1.1660105810438.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T040000-20220809T055959-1_minutes-v1.1660113077872.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T060000-20220809T075959-1_minutes-v1.1660120262864.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T080000-20220809T095959-1_minutes-v1.1660127500337.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T100000-20220809T115959-1_minutes-v1.1660134680885.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T120000-20220809T135959-1_minutes-v1.1660141814933.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T140000-20220809T155959-1_minutes-v1.1660149020861.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T160000-20220809T175959-1_minutes-v1.1660156212997.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T180000-20220809T195959-1_minutes-v1.1660163473428.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T200000-20220809T215959-1_minutes-v1.1660170728344.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220809T220000-20220809T235959-1_minutes-v1.1660178020430.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T000000-20220810T015959-1_minutes-v1.1660185046067.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T020000-20220810T035959-1_minutes-v1.1660192245348.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T040000-20220810T055959-1_minutes-v1.1660199479354.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T060000-20220810T075959-1_minutes-v1.1660206646491.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T080000-20220810T095959-1_minutes-v1.1660213862874.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T100000-20220810T115959-1_minutes-v1.1660221020000.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T120000-20220810T135959-1_minutes-v1.1660228235210.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T140000-20220810T155959-1_minutes-v1.1660235426308.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T160000-20220810T175959-1_minutes-v1.1660242625561.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T180000-20220810T195959-1_minutes-v1.1660249895470.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T200000-20220810T215959-1_minutes-v1.1660257085500.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220810T220000-20220810T235959-1_minutes-v1.1660264245308.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T000000-20220811T015959-1_minutes-v1.1660271503689.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T020000-20220811T035959-1_minutes-v1.1660278620419.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T040000-20220811T055959-1_minutes-v1.1660285865770.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T060000-20220811T075959-1_minutes-v1.1660293012997.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T080000-20220811T095959-1_minutes-v1.1660300287549.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T100000-20220811T115959-1_minutes-v1.1660307457565.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T120000-20220811T135959-1_minutes-v1.1660314640600.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T140000-20220811T155959-1_minutes-v1.1660321830465.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T160000-20220811T175959-1_minutes-v1.1660329005711.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T180000-20220811T195959-1_minutes-v1.1660336235740.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T200000-20220811T215959-1_minutes-v1.1660343457652.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220811T220000-20220811T235959-1_minutes-v1.1660350700480.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T000000-20220812T015959-1_minutes-v1.1660357808678.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T020000-20220812T035959-1_minutes-v1.1660365045289.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T040000-20220812T055959-1_minutes-v1.1660372245530.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T060000-20220812T075959-1_minutes-v1.1660379472628.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T080000-20220812T095959-1_minutes-v1.1660386657398.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T100000-20220812T115959-1_minutes-v1.1660393845514.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T120000-20220812T135959-1_minutes-v1.1660401030818.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T140000-20220812T155959-1_minutes-v1.1660408315635.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T160000-20220812T175959-1_minutes-v1.1660415413829.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T180000-20220812T195959-1_minutes-v1.1660422675276.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T200000-20220812T215959-1_minutes-v1.1660429863831.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220812T220000-20220812T235959-1_minutes-v1.1660437115442.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T000000-20220813T015959-1_minutes-v1.1660444282965.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T020000-20220813T035959-1_minutes-v1.1660451448092.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T040000-20220813T055959-1_minutes-v1.1660458638359.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T060000-20220813T075959-1_minutes-v1.1660465870201.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T080000-20220813T095959-1_minutes-v1.1660473050501.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T100000-20220813T115959-1_minutes-v1.1660480223450.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T120000-20220813T135959-1_minutes-v1.1660487507831.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T140000-20220813T155959-1_minutes-v1.1660494683118.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T160000-20220813T175959-1_minutes-v1.1660501856336.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T180000-20220813T195959-1_minutes-v1.1660509072789.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T200000-20220813T215959-1_minutes-v1.1660516210285.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220813T220000-20220813T235959-1_minutes-v1.1660523621292.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T000000-20220814T015959-1_minutes-v1.1660530620356.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T020000-20220814T035959-1_minutes-v1.1660537873150.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T040000-20220814T055959-1_minutes-v1.1660545057920.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T060000-20220814T075959-1_minutes-v1.1660552235137.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T080000-20220814T095959-1_minutes-v1.1660559467822.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T100000-20220814T115959-1_minutes-v1.1660566619950.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T120000-20220814T135959-1_minutes-v1.1660573813236.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T140000-20220814T155959-1_minutes-v1.1660581037964.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T160000-20220814T175959-1_minutes-v1.1660588205643.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T180000-20220814T195959-1_minutes-v1.1660595480248.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T200000-20220814T215959-1_minutes-v1.1660602617456.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220814T220000-20220814T235959-1_minutes-v1.1660609876449.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T000000-20220815T015959-1_minutes-v1.1660617105527.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T020000-20220815T035959-1_minutes-v1.1660624204704.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T040000-20220815T055959-1_minutes-v1.1660631482868.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T060000-20220815T075959-1_minutes-v1.1660638655591.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T080000-20220815T095959-1_minutes-v1.1660645941128.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T100000-20220815T115959-1_minutes-v1.1660653080647.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T120000-20220815T135959-1_minutes-v1.1660660262764.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T140000-20220815T155959-1_minutes-v1.1660667413500.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T160000-20220815T175959-1_minutes-v1.1660674653114.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T180000-20220815T195959-1_minutes-v1.1660681854613.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T200000-20220815T215959-1_minutes-v1.1660689005588.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220815T220000-20220815T235959-1_minutes-v1.1660696462940.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T000000-20220816T015959-1_minutes-v1.1660703427591.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T020000-20220816T035959-1_minutes-v1.1660710685890.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T040000-20220816T055959-1_minutes-v1.1660717925400.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T060000-20220816T075959-1_minutes-v1.1660725035216.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T080000-20220816T095959-1_minutes-v1.1660732232311.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T100000-20220816T115959-1_minutes-v1.1660739445816.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T120000-20220816T135959-1_minutes-v1.1660746658433.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T140000-20220816T155959-1_minutes-v1.1660753810389.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T160000-20220816T175959-1_minutes-v1.1660761040890.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T180000-20220816T195959-1_minutes-v1.1660768285151.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T200000-20220816T215959-1_minutes-v1.1660775495298.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220816T220000-20220816T235959-1_minutes-v1.1660782646169.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T000000-20220817T015959-1_minutes-v1.1660789905812.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T020000-20220817T035959-1_minutes-v1.1660797060191.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T040000-20220817T055959-1_minutes-v1.1660804273440.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T060000-20220817T075959-1_minutes-v1.1660811438547.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T080000-20220817T095959-1_minutes-v1.1660818640235.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T100000-20220817T115959-1_minutes-v1.1660825920518.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T120000-20220817T135959-1_minutes-v1.1660833072687.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T140000-20220817T155959-1_minutes-v1.1660840215110.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T160000-20220817T175959-1_minutes-v1.1660847501111.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T180000-20220817T195959-1_minutes-v1.1660854670394.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T200000-20220817T215959-1_minutes-v1.1660861883925.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220817T220000-20220817T235959-1_minutes-v1.1660869065169.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T000000-20220818T015959-1_minutes-v1.1660876217280.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T020000-20220818T035959-1_minutes-v1.1660883413302.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T040000-20220818T055959-1_minutes-v1.1660890647199.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T060000-20220818T075959-1_minutes-v1.1660897880720.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T080000-20220818T095959-1_minutes-v1.1660905030081.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T100000-20220818T115959-1_minutes-v1.1660912235554.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T120000-20220818T135959-1_minutes-v1.1660919520733.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T140000-20220818T155959-1_minutes-v1.1660926669350.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T160000-20220818T175959-1_minutes-v1.1660933875228.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T180000-20220818T195959-1_minutes-v1.1660941049931.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T200000-20220818T215959-1_minutes-v1.1660948230421.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220818T220000-20220818T235959-1_minutes-v1.1660955440813.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220819T000000-20220819T015959-1_minutes-v1.1660962645230.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220819T020000-20220819T035959-1_minutes-v1.1660969825931.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20220819T040000-20220819T055959-1_minutes-v1.1660977014213.nc
# ...
# saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T120000-20221019T135959-1_minutes-v1.1666276248919.nc filesize too small. skipped
# saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T140000-20221019T155959-1_minutes-v1.1666283405273.nc filesize too small. skipped
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T160000-20221019T175959-1_minutes-v1.1666290616786.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T180000-20221019T195959-1_minutes-v1.1666297814471.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T200000-20221019T215959-1_minutes-v1.1666305077322.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221019T220000-20221019T235959-1_minutes-v1.1666312252578.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T000000-20221020T015959-1_minutes-v1.1666319464284.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T020000-20221020T035959-1_minutes-v1.1666326651867.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T040000-20221020T055959-1_minutes-v1.1666333804913.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T060000-20221020T075959-1_minutes-v1.1666341009299.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T080000-20221020T095959-1_minutes-v1.1666348226722.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T100000-20221020T115959-1_minutes-v1.1666355488477.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T120000-20221020T135959-1_minutes-v1.1666362629534.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T140000-20221020T155959-1_minutes-v1.1666369842083.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T160000-20221020T175959-1_minutes-v1.1666377021810.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T180000-20221020T195959-1_minutes-v1.1666384279786.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T200000-20221020T215959-1_minutes-v1.1666391430516.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221020T220000-20221020T235959-1_minutes-v1.1666398689751.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T000000-20221021T015959-1_minutes-v1.1666405811522.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T020000-20221021T035959-1_minutes-v1.1666413068896.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T040000-20221021T055959-1_minutes-v1.1666420230700.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T060000-20221021T075959-1_minutes-v1.1666427418127.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T080000-20221021T095959-1_minutes-v1.1666434615434.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T100000-20221021T115959-1_minutes-v1.1666441849435.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T120000-20221021T135959-1_minutes-v1.1666449047222.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T140000-20221021T155959-1_minutes-v1.1666456228567.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T160000-20221021T175959-1_minutes-v1.1666463411415.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T180000-20221021T195959-1_minutes-v1.1666470617080.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T200000-20221021T215959-1_minutes-v1.1666477821489.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221021T220000-20221021T235959-1_minutes-v1.1666485128930.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T000000-20221022T015959-1_minutes-v1.1666492289987.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T020000-20221022T035959-1_minutes-v1.1666499458654.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T040000-20221022T055959-1_minutes-v1.1666506649001.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T060000-20221022T075959-1_minutes-v1.1666513837709.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T080000-20221022T095959-1_minutes-v1.1666521019543.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T100000-20221022T115959-1_minutes-v1.1666528234618.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T120000-20221022T135959-1_minutes-v1.1666535432875.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T140000-20221022T155959-1_minutes-v1.1666542646212.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T160000-20221022T175959-1_minutes-v1.1666549814398.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T180000-20221022T195959-1_minutes-v1.1666557011798.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T200000-20221022T215959-1_minutes-v1.1666564252005.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221022T220000-20221022T235959-1_minutes-v1.1666571431973.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T000000-20221023T015959-1_minutes-v1.1666578605350.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T020000-20221023T035959-1_minutes-v1.1666585836026.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T040000-20221023T055959-1_minutes-v1.1666593064496.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T060000-20221023T075959-1_minutes-v1.1666600244745.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T080000-20221023T095959-1_minutes-v1.1666607468869.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T100000-20221023T115959-1_minutes-v1.1666614663454.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T120000-20221023T135959-1_minutes-v1.1666621816790.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T140000-20221023T155959-1_minutes-v1.1666629049804.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T160000-20221023T175959-1_minutes-v1.1666636246711.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T180000-20221023T195959-1_minutes-v1.1666643456904.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T200000-20221023T215959-1_minutes-v1.1666652896042.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221023T220000-20221023T235959-1_minutes-v1.1666657884076.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T000000-20221024T015959-1_minutes-v1.1666665019449.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T020000-20221024T035959-1_minutes-v1.1666672222873.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T040000-20221024T055959-1_minutes-v1.1666679417639.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T060000-20221024T075959-1_minutes-v1.1666686617599.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T080000-20221024T095959-1_minutes-v1.1666693806629.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T100000-20221024T115959-1_minutes-v1.1666701004652.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T120000-20221024T135959-1_minutes-v1.1666708212110.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T140000-20221024T155959-1_minutes-v1.1666715412064.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T160000-20221024T175959-1_minutes-v1.1666722616212.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T180000-20221024T195959-1_minutes-v1.1666729820244.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T200000-20221024T215959-1_minutes-v1.1666737012088.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221024T220000-20221024T235959-1_minutes-v1.1666744240179.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T000000-20221025T015959-1_minutes-v1.1666751410926.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T020000-20221025T035959-1_minutes-v1.1666758619071.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T040000-20221025T055959-1_minutes-v1.1666765809137.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T060000-20221025T075959-1_minutes-v1.1666773015597.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T080000-20221025T095959-1_minutes-v1.1666780211831.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T100000-20221025T115959-1_minutes-v1.1666787418136.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T120000-20221025T135959-1_minutes-v1.1666794614195.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T140000-20221025T155959-1_minutes-v1.1666801803902.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T160000-20221025T175959-1_minutes-v1.1666809011615.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T180000-20221025T195959-1_minutes-v1.1666816203754.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T200000-20221025T215959-1_minutes-v1.1666823416167.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221025T220000-20221025T235959-1_minutes-v1.1666830637868.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T000000-20221026T015959-1_minutes-v1.1666837805375.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T020000-20221026T035959-1_minutes-v1.1666845007902.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T040000-20221026T055959-1_minutes-v1.1666852205542.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T060000-20221026T075959-1_minutes-v1.1666859405858.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T080000-20221026T095959-1_minutes-v1.1666866616101.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T100000-20221026T115959-1_minutes-v1.1666873807615.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T120000-20221026T135959-1_minutes-v1.1666881003775.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T140000-20221026T155959-1_minutes-v1.1666888206413.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T160000-20221026T175959-1_minutes-v1.1666895405190.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T180000-20221026T195959-1_minutes-v1.1666902605732.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T200000-20221026T215959-1_minutes-v1.1666909815873.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221026T220000-20221026T235959-1_minutes-v1.1666917027757.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T000000-20221027T015959-1_minutes-v1.1666924211564.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T020000-20221027T035959-1_minutes-v1.1666931412212.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T040000-20221027T055959-1_minutes-v1.1666938604385.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T060000-20221027T075959-1_minutes-v1.1666945811871.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T080000-20221027T095959-1_minutes-v1.1666953007757.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T100000-20221027T115959-1_minutes-v1.1666960212714.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T120000-20221027T135959-1_minutes-v1.1666967414568.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T140000-20221027T155959-1_minutes-v1.1666974612731.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T160000-20221027T175959-1_minutes-v1.1666981811842.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T180000-20221027T195959-1_minutes-v1.1666989010108.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T200000-20221027T215959-1_minutes-v1.1666996205881.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221027T220000-20221027T235959-1_minutes-v1.1667003428299.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T000000-20221028T015959-1_minutes-v1.1667010613152.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T020000-20221028T035959-1_minutes-v1.1667017805708.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T040000-20221028T055959-1_minutes-v1.1667025009960.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T060000-20221028T075959-1_minutes-v1.1667032209748.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T080000-20221028T095959-1_minutes-v1.1667039414961.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T100000-20221028T115959-1_minutes-v1.1667046603856.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T120000-20221028T135959-1_minutes-v1.1667053810196.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T140000-20221028T155959-1_minutes-v1.1667061005896.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T160000-20221028T175959-1_minutes-v1.1667068213203.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T180000-20221028T195959-1_minutes-v1.1667075411669.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T200000-20221028T215959-1_minutes-v1.1667082614845.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221028T220000-20221028T235959-1_minutes-v1.1667089825812.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T000000-20221029T015959-1_minutes-v1.1667097003630.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T020000-20221029T035959-1_minutes-v1.1667104210024.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T040000-20221029T055959-1_minutes-v1.1667111411666.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T060000-20221029T075959-1_minutes-v1.1667118610792.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T080000-20221029T095959-1_minutes-v1.1667125811087.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T100000-20221029T115959-1_minutes-v1.1667133006105.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T120000-20221029T135959-1_minutes-v1.1667140213941.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T140000-20221029T155959-1_minutes-v1.1667147408695.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T160000-20221029T175959-1_minutes-v1.1667154615812.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T180000-20221029T195959-1_minutes-v1.1667161808025.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T200000-20221029T215959-1_minutes-v1.1667169011795.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221029T220000-20221029T235959-1_minutes-v1.1667176215287.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T000000-20221030T015959-1_minutes-v1.1667183414842.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T020000-20221030T035959-1_minutes-v1.1667190609860.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T040000-20221030T055959-1_minutes-v1.1667197810573.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T060000-20221030T075959-1_minutes-v1.1667205004602.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T080000-20221030T095959-1_minutes-v1.1667212205984.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T100000-20221030T115959-1_minutes-v1.1667219406795.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T120000-20221030T135959-1_minutes-v1.1667226610800.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T140000-20221030T155959-1_minutes-v1.1667233805225.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T160000-20221030T175959-1_minutes-v1.1667241006047.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T180000-20221030T195959-1_minutes-v1.1667248208092.nc
# Done saildrone-gen_6-hurricane_monitoring_2022-sd1031-20221030T200000-20221030T215959-1_minutes-v1.1667255411048.nc

# %%
print(len(vars_dic.keys()), len(vars_dic_attr.keys()))
# Out:
# 23 66

# %%
### plot time intervals (time(i+1)-time(i)) and print time gaps
fig, axes = plt.subplots(1)
fig.set_size_inches(22,3)
test = vars_dic['time']
dtime = np.array([datetime.datetime(1970,1,1)+datetime.timedelta(seconds= vars_dic['time'][i]) for i in range(len(vars_dic['time']))])
dtest = np.array([(test[i+1]-test[i])/3600 for i in range( len(test)-1 )]) # 
plt.semilogy(dtime[:-1],dtest)
ddays = (np.max(dtime)-np.min(dtime)).days
xticks = [np.min(dtime)+datetime.timedelta(days=5*i) for i in range(ddays)]
xtickslabel = [xticks[i].strftime('%m/%d') for i in range(ddays)]
plt.xticks(xticks)
plt.gca().set_xticklabels(xtickslabel, rotation=90)
plt.ylabel('time difference (hours)')
plt.xlim([dtime[0],dtime[-1]])
plt.grid()
print('min time difference=',np.min(dtest)*3600,'sec')
print('1st & last time in file:',dtime[0].strftime('%m/%d %H:%MZ'),dtime[-1].strftime('%m/%d %H:%MZ'))
### find data gaps
d5min = (datetime.datetime(2019,1,1,0,5,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d10min = (datetime.datetime(2019,1,1,0,10,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d30min = (datetime.datetime(2019,1,1,0,30,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
d60min = (datetime.datetime(2019,1,1,1,0,0)-datetime.datetime(2019,1,1)).total_seconds()/3600
i_tgap = np.where( dtest > d30min )[0]
print(len(i_tgap),'time gaps that are > 30 min')
print('The corresponding time gaps (in mins)',dtest[i_tgap]*60)
for i in range( len(i_tgap) ):
    print(dtime[i_tgap[i]].strftime('%m/%d %H:%MZ'),'-',dtime[i_tgap[i]+1].strftime('%m/%d %H:%MZ'))

plt.suptitle('Time intervals (t(i+1)-t(i)): Hurricane '+year+' - '+platf_num)
### save figure
# fig.savefig(pathout+'time_intervals_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# min time difference= 60.0 sec
# 1st & last time in file: 07/15 20:00Z 10/30 21:59Z
# 4 time gaps that are > 30 min
# The corresponding time gaps (in mins) [601. 121. 121. 241.]
# 10/16 23:59Z - 10/17 10:00Z
# 10/19 01:59Z - 10/19 04:00Z
# 10/19 07:59Z - 10/19 10:00Z
# 10/19 11:59Z - 10/19 16:00Z
# Text(0.5, 0.98, 'Time intervals (t(i+1)-t(i)): Hurricane 2022 - 1031')

# %%
### plot merged raw data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['latitude','longitude','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV','WIND_MEASUREMENT_HEIGHT_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    print(vkey)
    data = vars_dic[vkey]
    h = plt.subplot(nrow,1,i+1)
    plt.plot(dtime,data,'.',ms=1)
    plt.xlim(tlim)
    plt.grid()
    plt.legend(h,labels=[vkey],loc='upper left')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_wind_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude', 'time']
# latitude
# /var/folders/hq/8x0c_cvs4651pwh9kv6t7_zc0000gq/T/ipykernel_5688/338490399.py:19: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# longitude
# UWND_MEAN
# UWND_STDDEV
# VWND_MEAN
# VWND_STDDEV
# GUST_WND_MEAN
# GUST_WND_STDDEV
# WIND_MEASUREMENT_HEIGHT_MEAN

# %%
### plot merged raw data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN','WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT']#,\
            #  'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
            #     'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    print(vkey)
    data = vars_dic[vkey]
    h = plt.subplot(nrow,1,i+1)
    plt.plot(dtime,data,'.',ms=1)
    plt.xlim(tlim)
    plt.grid()
    plt.legend(h,labels=[vkey],loc='upper left')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_met_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude', 'time']
# TEMP_AIR_MEAN
# /var/folders/hq/8x0c_cvs4651pwh9kv6t7_zc0000gq/T/ipykernel_5688/2028028535.py:21: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# RH_MEAN
# BARO_PRES_MEAN
# PAR_AIR_MEAN
# WAVE_DOMINANT_PERIOD
# WAVE_SIGNIFICANT_HEIGHT

# %%
### plot merged raw data (1D data)
print(list(vars_dic.keys()))
vars_plot = ['TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
             'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
nrow = len(vars_plot)
tlim = [dtime[0],dtime[-1]]
### initiate plot
plt.clf()
plt.rcParams.update({'font.size': 14})
fig, axes = plt.subplots(nrow,1)
fig.set_size_inches(20,16)
for i in range( nrow ):
    vkey = vars_plot[i]
    print(vkey)
    data = vars_dic[vkey]
    h = plt.subplot(nrow,1,i+1)
    plt.plot(dtime,data,'.',ms=1)
    plt.xlim(tlim)
    plt.grid()
    plt.legend(h,labels=[vkey],loc='upper left')
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.1,hspace=0.05)
plt.suptitle('Merged Raw Timeseries: Hurricane '+year+' - '+platf_num)
fig.savefig(pathout+'merge_raw_sea_1D_'+year+'-'+platf_num+'.png', dpi=300,bbox_inches='tight')
# Out:
# ['UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN', 'TEMP_AIR_MEAN', 'RH_MEAN', 'BARO_PRES_MEAN', 'PAR_AIR_MEAN', 'WAVE_DOMINANT_PERIOD', 'WAVE_SIGNIFICANT_HEIGHT', 'TEMP_DEPTH_HALFMETER_MEAN', 'TEMP_SBE37_MEAN', 'TEMP_SBE37_STDDEV', 'SAL_SBE37_MEAN', 'SAL_SBE37_STDDEV', 'WATER_CURRENT_SPEED_MEAN', 'WATER_CURRENT_DIRECTION_MEAN', 'latitude', 'longitude', 'time']
# TEMP_DEPTH_HALFMETER_MEAN
# /var/folders/hq/8x0c_cvs4651pwh9kv6t7_zc0000gq/T/ipykernel_5688/1729066472.py:20: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(h,labels=[vkey],loc='upper left')
# TEMP_SBE37_MEAN
# TEMP_SBE37_STDDEV
# SAL_SBE37_MEAN
# SAL_SBE37_STDDEV
# WATER_CURRENT_SPEED_MEAN
# WATER_CURRENT_DIRECTION_MEAN

# %%
### write the merged data to netcdf file: https://unidata.github.io/python-training/workshop/Bonus/netcdf-writing/
try: ncfile.close()  # just to be safe, make sure dataset is not already open.
except: pass
ncfile = nc.Dataset('airsea-1min-merge-'+year+'-SD'+platf_num+'.nc',mode='w',format='NETCDF4_CLASSIC') 
print(ncfile)
### creating dimensions
time_dim = ncfile.createDimension('time', len(dtime)) # unlimited axis (can be appended to).
for dim in ncfile.dimensions.items():
    print(dim)
### creating attributes
ncfile.title='Merged files for SD-'+platf_num
print(ncfile.title)
ncfile.subtitle="Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute."
print(ncfile.subtitle)
print(ncfile)
### move the writing data to new variables
### compute the time as seconds since 2022-01-01
time_out = np.array([(dtime[i]-datetime.datetime(int(year),1,1)).total_seconds() for i in range(len(dtime))])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# ('time', <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 153120)
# Merged files for SD-1031
# Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: Merged files for SD-1031
#     subtitle: Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
#     dimensions(sizes): time(153120)
#     variables(dimensions):
#     groups:

# %%
def isMonotonic(A):
    return (all(A[i] <= A[i + 1] for i in range(len(A) - 1)) or
            all(A[i] >= A[i + 1] for i in range(len(A) - 1)))
print('is time_out monotonic? -->', isMonotonic(time_out))

plt.subplot(3,1,1)
plt.plot(time_out,'.')
plt.subplot(3,1,2)
plt.semilogy(np.diff(np.sort(time_out)),'.')
plt.grid()
plt.subplot(3,1,3)
plt.hist(np.diff(np.sort(time_out)))
# Out:
# is time_out monotonic? --> True
# (array([1.53115e+05, 0.00000e+00, 2.00000e+00, 0.00000e+00, 1.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([   60.,  3660.,  7260., 10860., 14460., 18060., 21660., 25260.,
#         28860., 32460., 36060.]),
#  <BarContainer object of 10 artists>)

# %%
### Creating variables: 'UWND_MEAN', 'UWND_STDDEV', 'VWND_MEAN', 'VWND_STDDEV', 'GUST_WND_MEAN', 'GUST_WND_STDDEV', 'WIND_MEASUREMENT_HEIGHT_MEAN'
time = ncfile.createVariable('time', np.float64, ('time',))
time.units = 'seconds since '+year+'-01-01'
time.long_name = 'time'
### 1D variables
vars_yes = ['latitude','longitude','UWND_MEAN','UWND_STDDEV','VWND_MEAN','VWND_STDDEV','GUST_WND_MEAN','GUST_WND_STDDEV',\
            'WIND_MEASUREMENT_HEIGHT_MEAN','TEMP_AIR_MEAN','RH_MEAN','BARO_PRES_MEAN','PAR_AIR_MEAN',\
                'WAVE_DOMINANT_PERIOD','WAVE_SIGNIFICANT_HEIGHT',\
                    'TEMP_DEPTH_HALFMETER_MEAN','TEMP_SBE37_MEAN','TEMP_SBE37_STDDEV','SAL_SBE37_MEAN','SAL_SBE37_STDDEV',\
                        'WATER_CURRENT_SPEED_MEAN','WATER_CURRENT_DIRECTION_MEAN']
### 1: (time,)
for i in range( len(vars_yes) ):
    vkey = vars_yes[i]
    ### create variables
    str_exec = vkey + "= ncfile.createVariable('" + vkey + "', np.float64, ('" + 'time' + "',))"
    exec(str_exec)
    print(i,str_exec)
    ### add attributes
    for a in range( len(attr) ):
        if (attr[a] == 'installed_height') & (vkey in vars_no_installed_height):
            pass
        else:
            str_exec = vkey + "."+ attr[a] + " = '"+ str( vars_dic_attr[vkey+'-'+attr[a]] ) + "'"
            exec(str_exec)
            print(a,str_exec)
# Out:
# 0 latitude= ncfile.createVariable('latitude', np.float64, ('time',))
# 0 latitude.long_name = 'Latitude'
# 1 latitude.units = 'degrees_north'
# 1 longitude= ncfile.createVariable('longitude', np.float64, ('time',))
# 0 longitude.long_name = 'Longitude'
# 1 longitude.units = 'degrees_east'
# 2 UWND_MEAN= ncfile.createVariable('UWND_MEAN', np.float64, ('time',))
# 0 UWND_MEAN.long_name = 'Eastward wind speed'
# 1 UWND_MEAN.units = 'm s-1'
# 2 UWND_MEAN.installed_height = '5.2'
# 3 UWND_STDDEV= ncfile.createVariable('UWND_STDDEV', np.float64, ('time',))
# 0 UWND_STDDEV.long_name = 'Eastward wind speed SD'
# 1 UWND_STDDEV.units = 'm s-1'
# 2 UWND_STDDEV.installed_height = '5.2'
# 4 VWND_MEAN= ncfile.createVariable('VWND_MEAN', np.float64, ('time',))
# 0 VWND_MEAN.long_name = 'Northward wind speed'
# 1 VWND_MEAN.units = 'm s-1'
# 2 VWND_MEAN.installed_height = '5.2'
# 5 VWND_STDDEV= ncfile.createVariable('VWND_STDDEV', np.float64, ('time',))
# 0 VWND_STDDEV.long_name = 'Northward wind speed SD'
# 1 VWND_STDDEV.units = 'm s-1'
# 2 VWND_STDDEV.installed_height = '5.2'
# 6 GUST_WND_MEAN= ncfile.createVariable('GUST_WND_MEAN', np.float64, ('time',))
# 0 GUST_WND_MEAN.long_name = 'Wind gust speed'
# 1 GUST_WND_MEAN.units = 'm s-1'
# 2 GUST_WND_MEAN.installed_height = '5.2'
# 7 GUST_WND_STDDEV= ncfile.createVariable('GUST_WND_STDDEV', np.float64, ('time',))
# 0 GUST_WND_STDDEV.long_name = 'Wind gust speed SD'
# 1 GUST_WND_STDDEV.units = 'm s-1'
# 2 GUST_WND_STDDEV.installed_height = '5.2'
# 8 WIND_MEASUREMENT_HEIGHT_MEAN= ncfile.createVariable('WIND_MEASUREMENT_HEIGHT_MEAN', np.float64, ('time',))
# 0 WIND_MEASUREMENT_HEIGHT_MEAN.long_name = 'Wind measurement height'
# 1 WIND_MEASUREMENT_HEIGHT_MEAN.units = 'm'
# 2 WIND_MEASUREMENT_HEIGHT_MEAN.installed_height = '5.2'
# 9 TEMP_AIR_MEAN= ncfile.createVariable('TEMP_AIR_MEAN', np.float64, ('time',))
# 0 TEMP_AIR_MEAN.long_name = 'Air temperature'
# 1 TEMP_AIR_MEAN.units = 'degrees_c'
# 2 TEMP_AIR_MEAN.installed_height = '2.3'
# 10 RH_MEAN= ncfile.createVariable('RH_MEAN', np.float64, ('time',))
# 0 RH_MEAN.long_name = 'Relative humidity'
# 1 RH_MEAN.units = 'percent'
# 2 RH_MEAN.installed_height = '2.3'
# 11 BARO_PRES_MEAN= ncfile.createVariable('BARO_PRES_MEAN', np.float64, ('time',))
# 0 BARO_PRES_MEAN.long_name = 'Air pressure'
# 1 BARO_PRES_MEAN.units = 'hPa'
# 2 BARO_PRES_MEAN.installed_height = '0.2'
# 12 PAR_AIR_MEAN= ncfile.createVariable('PAR_AIR_MEAN', np.float64, ('time',))
# 0 PAR_AIR_MEAN.long_name = 'Photosynthetically active radiation in air'
# 1 PAR_AIR_MEAN.units = 'micromol s-1 m-2'
# 2 PAR_AIR_MEAN.installed_height = '2.6'
# 13 WAVE_DOMINANT_PERIOD= ncfile.createVariable('WAVE_DOMINANT_PERIOD', np.float64, ('time',))
# 0 WAVE_DOMINANT_PERIOD.long_name = 'Dominant wave period'
# 1 WAVE_DOMINANT_PERIOD.units = 's'
# 2 WAVE_DOMINANT_PERIOD.installed_height = '0.34'
# 14 WAVE_SIGNIFICANT_HEIGHT= ncfile.createVariable('WAVE_SIGNIFICANT_HEIGHT', np.float64, ('time',))
# 0 WAVE_SIGNIFICANT_HEIGHT.long_name = 'Significant wave height'
# 1 WAVE_SIGNIFICANT_HEIGHT.units = 'm'
# 2 WAVE_SIGNIFICANT_HEIGHT.installed_height = '0.34'
# 15 TEMP_DEPTH_HALFMETER_MEAN= ncfile.createVariable('TEMP_DEPTH_HALFMETER_MEAN', np.float64, ('time',))
# 0 TEMP_DEPTH_HALFMETER_MEAN.long_name = 'Seawater temperature at depth of 0.5m'
# 1 TEMP_DEPTH_HALFMETER_MEAN.units = 'degrees_c'
# 2 TEMP_DEPTH_HALFMETER_MEAN.installed_height = '-0.5'
# 16 TEMP_SBE37_MEAN= ncfile.createVariable('TEMP_SBE37_MEAN', np.float64, ('time',))
# 0 TEMP_SBE37_MEAN.long_name = 'Seawater temperature'
# 1 TEMP_SBE37_MEAN.units = 'degrees_c'
# 2 TEMP_SBE37_MEAN.installed_height = '-0.5'
# 17 TEMP_SBE37_STDDEV= ncfile.createVariable('TEMP_SBE37_STDDEV', np.float64, ('time',))
# 0 TEMP_SBE37_STDDEV.long_name = 'Seawater temperature SD'
# 1 TEMP_SBE37_STDDEV.units = 'degrees_c'
# 2 TEMP_SBE37_STDDEV.installed_height = '-0.5'
# 18 SAL_SBE37_MEAN= ncfile.createVariable('SAL_SBE37_MEAN', np.float64, ('time',))
# 0 SAL_SBE37_MEAN.long_name = 'Seawater salinity'
# 1 SAL_SBE37_MEAN.units = '1'
# 2 SAL_SBE37_MEAN.installed_height = '-0.5'
# 19 SAL_SBE37_STDDEV= ncfile.createVariable('SAL_SBE37_STDDEV', np.float64, ('time',))
# 0 SAL_SBE37_STDDEV.long_name = 'Seawater salinity SD'
# 1 SAL_SBE37_STDDEV.units = '1'
# 2 SAL_SBE37_STDDEV.installed_height = '-0.5'
# 20 WATER_CURRENT_SPEED_MEAN= ncfile.createVariable('WATER_CURRENT_SPEED_MEAN', np.float64, ('time',))
# 0 WATER_CURRENT_SPEED_MEAN.long_name = 'Water Current Speed'
# 1 WATER_CURRENT_SPEED_MEAN.units = 'm s-1'
# 2 WATER_CURRENT_SPEED_MEAN.installed_height = '-1.9'
# 21 WATER_CURRENT_DIRECTION_MEAN= ncfile.createVariable('WATER_CURRENT_DIRECTION_MEAN', np.float64, ('time',))
# 0 WATER_CURRENT_DIRECTION_MEAN.long_name = 'Water Current Direction'
# 1 WATER_CURRENT_DIRECTION_MEAN.units = 'degree'
# 2 WATER_CURRENT_DIRECTION_MEAN.installed_height = '-1.9'

# %%
### writing data
# Note: the ":" is necessary in these "write" statements
time[:] = time_out
for i in range( len(vars_yes) ):
    str_exec = vars_yes[i] + "[:]= vars_dic['" + vars_yes[i] + "']"
    exec(str_exec)    
print(ncfile)
# close the Dataset.
ncfile.close(); print('Dataset is closed!')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: Merged files for SD-1031
#     subtitle: Only selected variables for COARE flux calculations are here. Temporal resolution is 1-minute.
#     dimensions(sizes): time(153120)
#     variables(dimensions): float64 time(time), float64 latitude(time), float64 longitude(time), float64 UWND_MEAN(time), float64 UWND_STDDEV(time), float64 VWND_MEAN(time), float64 VWND_STDDEV(time), float64 GUST_WND_MEAN(time), float64 GUST_WND_STDDEV(time), float64 WIND_MEASUREMENT_HEIGHT_MEAN(time), float64 TEMP_AIR_MEAN(time), float64 RH_MEAN(time), float64 BARO_PRES_MEAN(time), float64 PAR_AIR_MEAN(time), float64 WAVE_DOMINANT_PERIOD(time), float64 WAVE_SIGNIFICANT_HEIGHT(time), float64 TEMP_DEPTH_HALFMETER_MEAN(time), float64 TEMP_SBE37_MEAN(time), float64 TEMP_SBE37_STDDEV(time), float64 SAL_SBE37_MEAN(time), float64 SAL_SBE37_STDDEV(time), float64 WATER_CURRENT_SPEED_MEAN(time), float64 WATER_CURRENT_DIRECTION_MEAN(time)
#     groups:
# Dataset is closed!
