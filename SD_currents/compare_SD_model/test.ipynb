# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

# %%
nrow = 2; ncol = 3
plt.subplots(nrows=nrow,ncols=ncol)
for i in range(6):
    plt.subplot(nrow,ncol,i+1)
    plt.plot(np.arange(0,i+1,1), np.arange(0,i+1,1),'-o')
    plt.xlabel('U$_{SD}$')
